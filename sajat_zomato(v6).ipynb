# %% [markdown]
# ## Adatok beolvasása

# %%
import pandas as pd
import os
def load_data(path):
 csv_path = os.path.join(path, "zomato.csv")
 return pd.read_csv(csv_path)

zomato = load_data("datasets")

# %% [markdown]
# Adatok összekeverése annak érdekében, hogy esetleges mintákat elimináljuk a kezdeti adatbázisban.

# %%
from sklearn.utils import shuffle
zomato = shuffle(zomato)
zomato.reset_index(inplace=True, drop=True)

# %%
backup_zomato = zomato.copy()

# %%
zomato
# Out:
#                                                      url  \
# 0      https://www.zomato.com/bangalore/chefs-cap-chi...
# 1      https://www.zomato.com/bangalore/shakesbierre-...
# 2      https://www.zomato.com/bangalore/spices-cv-ram...
# 3      https://www.zomato.com/bangalore/the-studio-ba...
# 4      https://www.zomato.com/bangalore/vegetarea-btm...
# 5      https://www.zomato.com/bangalore/nawabi-kamman...
# 6      https://www.zomato.com/bangalore/fill-n-chill-...
# 7      https://www.zomato.com/bangalore/ambur-hot-dum...
# 8      https://www.zomato.com/bangalore/prems-graama-...
# 9      https://www.zomato.com/bangalore/bright-go-nut...
# 10     https://www.zomato.com/bangalore/bakers-home-b...
# 11     https://www.zomato.com/bangalore/new-mangalore...
# 12     https://www.zomato.com/bangalore/bruncherz-btm...
# 13     https://www.zomato.com/bangalore/i-cool-jp-nag...
# 14     https://www.zomato.com/bangalore/hyderabad-baw...
# 15     https://www.zomato.com/bangalore/juice-junctio...
# 16     https://www.zomato.com/bangalore/chungs-pavili...
# 17     https://www.zomato.com/bangalore/pizza-hut-3-w...
# 18     https://www.zomato.com/bangalore/new-punjabi-p...
# 19     https://www.zomato.com/bangalore/khaja-point-b...
# 20     https://www.zomato.com/bangalore/bobs-bar-kora...
# 21     https://www.zomato.com/bangalore/samosa-expres...
# 22     https://www.zomato.com/bangalore/nalamaharaja-...
# 23     https://www.zomato.com/bangalore/ghar-ki-rasoi...
# 24     https://www.zomato.com/bangalore/best-brews-fo...
# 25     https://www.zomato.com/bangalore/mustard-food-...
# 26     https://www.zomato.com/bangalore/just-shawarma...
# 27     https://www.zomato.com/bangalore/k-b-r-fast-fo...
# 28     https://www.zomato.com/bangalore/bisi-thindi-k...
# 29     https://www.zomato.com/bangalore/kfc-cunningha...
# ...                                                  ...
# 51687  https://www.zomato.com/hunger-hitman?context=e...
# 51688  https://www.zomato.com/bangalore/juiced-burger...
# 51689  https://www.zomato.com/bangalore/ssv-upahar-ja...
# 51690  https://www.zomato.com/bangalore/frosty-fills-...
# 51691  https://www.zomato.com/bangalore/jeffs-royal-o...
# 51692  https://www.zomato.com/bangalore/al-baith-kora...
# 51693  https://www.zomato.com/bangalore/oil-pump-1-ko...
# 51694  https://www.zomato.com/bangalore/mayura-grand-...
# 51695  https://www.zomato.com/bangalore/the-biere-clu...
# 51696  https://www.zomato.com/bangalore/radha-rani-br...
# 51697  https://www.zomato.com/bangalore/just-shawarma...
# 51698  https://www.zomato.com/bangalore/ginseng-royal...
# 51699  https://www.zomato.com/bangalore/junkealth-jp-...
# 51700  https://www.zomato.com/bangalore/namma-biriyan...
# 51701  https://www.zomato.com/bangalore/the-dragon-ex...
# 51702  https://www.zomato.com/bangalore/joses-mess-bt...
# 51703  https://www.zomato.com/bangalore/taco-bell-ind...
# 51704  https://www.zomato.com/bangalore/dinepost9-ban...
# 51705  https://www.zomato.com/bangalore/petoo-commerc...
# 51706  https://www.zomato.com/bangalore/velvet-kitche...
# 51707  https://www.zomato.com/bangalore/urban-spoon-b...
# 51708  https://www.zomato.com/bangalore/fresh-presser...
# 51709  https://www.zomato.com/bangalore/roll-over-jay...
# 51710  https://www.zomato.com/bangalore/fabcafe-mg-ro...
# 51711  https://www.zomato.com/bangalore/meghana-foods...
# 51712  https://www.zomato.com/bangalore/rk-fast-food-...
# 51713  https://www.zomato.com/bangalore/aqua-the-park...
# 51714  https://www.zomato.com/bangalore/the-cake-city...
# 51715  https://www.zomato.com/bangalore/new-udupi-dha...
# 51716  https://www.zomato.com/bangalore/jcl-canteen-s...
#
#                                                  address  \
# 0      23, 5th Cross, BDA Layout, Murgehpalaya, Old A...
# 1             Level 5, Eva Mall, Brigade Road, Bangalore
# 2      5, Bagmane Tech Park Back Gate, Byrasandra Mai...
# 3      Orion Mall, Brigade Gateway, Dr. Rajkumar Road...
# 4      1, 100 Feet Ring Road, 1st Phase, 2nd Stage, B...
# 5      605, 4th Cross, HRBR Layout, Kalyan Nagar, Kam...
# 6      107/2, 80 Feet Road, 4th Block, Koramangala 4t...
# 7      91, General KS Thimayya Road, KSRTC Layout, Sr...
# 8      234, 32 A Cross, 2nd Main Road, 7th Block, Jay...
# 9          14, 24th Main, 6th Phase, JP Nagar, Bangalore
# 10     Shop No 1, 15th Cross, DR BR Ambedkar Circle, ...
# 11     8th Cross Road, Venkatapura, Teachers Colony, ...
# 12            1st Main, S.G Palya, Christ Pool Main Road
# 13     14/1, 23rd Main Road, Nagaraja Garden, JP Naga...
# 14     4,30th Cross, Jayanagar T Block,Tilaknagar Mai...
# 15     127/4, 5th Block, KHB MIG Colony, Near Jyothi ...
# 16                       #3047, 80 ft. Road, Indiranagar
# 17     LG/02, Lower Basement, Ascendas Park Square Ma...
# 18     1527 / 784 Sector 3, 764 BBMP Khatha, HSR, Ban...
# 19     1st Main, 1st Cross, Maruthinagar Extension, M...
# 20     1, Raheja Arcade, Koramangala 7th Block, Banga...
# 21     88/26, Mariyappa Bulding, Tavarkere Main Road,...
# 22     976, 1st Floor, Above SBI Bank, Vidyaranyapura...
# 23     Devarabeesanahalli, Opposite Sakra World Hospi...
# 24     Four Points by Sheraton Bengaluru, 43/3, White...
# 25     1050, 1st Floor, 80 Feet Road, 3rd Block, Kora...
# 26     SJR Equinox, Near Velankani Software Gate 3, D...
# 27     Richmond Circle, Opposite PF Office, Richmond ...
# 28     21, Ground Floor, Praise the Lord Mansion, Neh...
# 29     Ground Floor, 14, HM Geneva House, Cunningham ...
# ...                                                  ...
# 51687                                      Delivery Only
# 51688                                      Delivery Only
# 51689   14/1, 8th Fmain, 3rd Block, Jayanagar, Bangalore
# 51690  Ground Floor, Opposite Central Mall, Bellandur...
# 51691  Royal Orchid Hotel, 1, Golf Arcade, HAL, Old A...
# 51692  4/1, 1st Main, Bhuvanappa Layout, Opposite For...
# 51693  897/B, 1st Floor, Above Bata Shoe Shop, Opposi...
# 51694  897/1, Venkat Reddy Layout, Koramangala 6th Bl...
# 51695  20/2, Vittal Mallya Road, Lavelle Road, Bangalore
# 51696  Opposite Brookefield Mall, Brookefield, Bangalore
# 51697  Shop 2, B.M.R Complex, Green Garden Layout, Th...
# 51698  Royal Orchid Hotel, 1, Golf Arcade, HAL, Old A...
# 51699                       JP Nagar, Phase 7, Bangalore
# 51700  63, 5th Block, Jyoti Nivas College Road, Benga...
# 51701  3rd Floor, Virginia Mall, Varthur Main Road, W...
# 51702  Maruthi Nagar Main Road, 9th Cross, BTM, Banga...
# 51703  Unit 840/1, 100 Feet Road, Binnamangala, 1st S...
# 51704  Bhuvanagiri Main Road, OMBR Layout, Kasturi Na...
# 51705  286, 2nd Floor, Commercial Plaza, Near Westsid...
# 51706  Shop 4 & 5, Vajrappa Building , Shantiniketan ...
# 51707  2, 1st Floor, 100 Feet Road, Koramangala 5th B...
# 51708  98/A, 17th B Main, Opposite China Pearl, Koram...
# 51709  1A/29 , Shop 2 , 27th Cross, Jayanagar, Bangalore
# 51710  18, First Floor, Ramanashree Arcade, MG Road, ...
# 51711  124, Near Jyothi Nivas College, 1st Cross, KHB...
# 51712  60, Near Sandhya Theatre, Madiwala, BTM, Benga...
# 51713       The Park Bangalore, 14/7, MG Road, Bangalore
# 51714  136/4, 1st Floor, Lalbagh Road, Shanti Nagar, ...
# 51715  TRR Complex, Ramappa Layout, Tavarekere Bus St...
# 51716  104, Narayana Pillai Street, Opp C Mart, Shiva...
#
#                                                     name online_order  \
# 0                  Chef's Cap Chinese Cuisine Restaurant          Yes
# 1                                           ShakesBierre           No
# 2                                                 Spices          Yes
# 3                                         The Studio Bar           No
# 4                                              Vegetarea          Yes
# 5                                                 Nawabi          Yes
# 6                           Fill N Chill Resto Bar & Pub          Yes
# 7                                  Ambur Hot Dum Biryani           No
# 8                                  Prems Graama Bhojanam          Yes
# 9                                         Bright Go Nuts           No
# 10                                          Baker's Home          Yes
# 11                              New Mangalore Lunch Home          Yes
# 12                                             Bruncherz           No
# 13                                                I Cool          Yes
# 14                                    Hyderabad Bawarchi           No
# 15                                        Juice Junction          Yes
# 16                                       Chungs Pavilion          Yes
# 17                                             Pizza Hut          Yes
# 18                       New Punjabi Pure Veg Restaurant          Yes
# 19                                           Khaja Point           No
# 20                                             Bob's Bar           No
# 21                                        Samosa Express          Yes
# 22                                          NalaMaharaja           No
# 23                                         Ghar Ki Rasoi          Yes
# 24     Best Brews - Four Points by Sheraton Bengaluru...           No
# 25                                    Mustard Food Court          Yes
# 26                                         Just Shawarma          Yes
# 27                                       K.B.R Fast Food           No
# 28                                           Bisi Thindi          Yes
# 29                                                   KFC          Yes
# ...                                                  ...          ...
# 51687                                      Hunger Hitman          Yes
# 51688                                      Juiced Burger          Yes
# 51689                                         SSV Upahar          Yes
# 51690                                       Frosty Fills          Yes
# 51691                        Jeff's - Royal Orchid Hotel           No
# 51692                                           Al Baith           No
# 51693                                           Oil Pump           No
# 51694                                       Mayura Grand           No
# 51695                                     The Biere Club          Yes
# 51696                                         Radha Rani          Yes
# 51697                                      Just Shawarma          Yes
# 51698                       Ginseng - Royal Orchid Hotel           No
# 51699                                          Junkealth           No
# 51700                                     Namma Biriyani          Yes
# 51701                                 The Dragon Express           No
# 51702                                        Jose's Mess           No
# 51703                                          Taco Bell          Yes
# 51704                                          DinePost9          Yes
# 51705                                              Petoo           No
# 51706                                     Velvet Kitchen          Yes
# 51707                      Urban Spoon Buffet Restaurant           No
# 51708                                Fresh Pressery Cafe          Yes
# 51709                                          Roll Over          Yes
# 51710                                            Fabcafe          Yes
# 51711                                      Meghana Foods          Yes
# 51712                                       RK Fast Food           No
# 51713                          Aqua - The Park Bangalore           No
# 51714                                      The Cake City          Yes
# 51715                                New Udupi Dharshini           No
# 51716                                        JCL Canteen           No
#
#       book_table    rate  votes                               phone  \
# 0             No  3.9 /5     37                      +91 7795346972
# 1            Yes  4.4 /5    409                        080 49653253
# 2             No  3.2 /5      6      +91 9148955589\n+91 9538909192
# 3             No  4.0 /5    775      +91 8022682181\n+91 9900816815
# 4             No   3.8/5     40                        080 43334333
# 5             No     NaN      0                      +91 9742588766
# 6            Yes  3.9 /5    598                      +91 9591989862
# 7             No   3.1/5      6                      +91 7259821185
# 8             No   4.3/5    325      080 26630542\r\n+91 9611980542
# 9             No     NaN      0                      +91 9164595191
# 10            No  3.9 /5    179      +91 8884000601\n+91 8884000605
# 11            No  3.8 /5     36                      +91 7022136720
# 12            No  3.5 /5     15    +91 9481160720\r\n+91 9900690335
# 13            No   4.0/5     77                      +91 8105392394
# 14            No   3.9/5    118    +91 8884979343\r\n+91 9985900859
# 15            No   3.9/5     69                        080 40927571
# 16            No   3.9/5    247        080 25254142\r\n080 25285403
# 17            No  3.7 /5    492                        080 30246398
# 18            No   3.5/5     10                      +91 9663357948
# 19            No     NEW      0                      +91 9886804017
# 20            No     NEW      0      +91 7829709340\n+91 8073135768
# 21            No   3.1/5      9  +91 7903952734\r\r\n+91 8046756446
# 22            No  3.3 /5      7        080 41604055\n+91 9620196962
# 23            No  3.7 /5     50                        080 49652795
# 24            No  3.6 /5     27                        080 40301477
# 25            No  3.6 /5    165                        080 40924441
# 26            No   3.9/5    176                      +91 7676764422
# 27            No     NaN      0                      +91 9886182692
# 28            No     NEW      0                      +91 7349446837
# 29            No   3.6/5    206                        080 33994444
# ...          ...     ...    ...                                 ...
# 51687         No   3.8/5    257                      +91 9742458090
# 51688         No   3.5/5      5    +91 8197470002\r\n+91 8033037777
# 51689         No     NaN      0                      +91 7022622678
# 51690         No  3.7 /5     10      +91 9896059300\n+91 9092358129
# 51691         No  3.9 /5     80                      +91 7980375965
# 51692         No     NaN      0                      +91 7619699355
# 51693         No  3.7 /5     68      +91 9986059256\n+91 9845039304
# 51694         No  3.5 /5     20                        080 25507070
# 51695        Yes   4.3/5   3485      +91 9986769776\r\n080 42134668
# 51696         No   3.3/5    244  +91 8792449564\r\r\n+91 9886595975
# 51697         No  3.8 /5    198      +91 9538589331\n+91 9791819153
# 51698        Yes   4.0/5    170    +91 9686611406\r\n+91 9902954007
# 51699         No     NaN      0                      +91 9880530105
# 51700         No   3.7/5     14                        080 43758178
# 51701         No     NaN      0                        080 67425009
# 51702         No   4.4/5    316                        080 26840905
# 51703         No   4.2/5    387                        080 48517087
# 51704         No   3.9/5    367                      +91 9632538674
# 51705         No  3.7 /5     32                      +91 9845008658
# 51706         No   3.5/5     15                      +91 9945575398
# 51707        Yes   3.5/5     32    +91 9900178610\r\n+91 9900178608
# 51708         No  4.1 /5    141                        080 41724989
# 51709         No   4.1/5    438    +91 8884942976\r\n+91 8884942900
# 51710        Yes  4.1 /5     60                        080 49652772
# 51711         No   4.4/5   7210                        080 49653429
# 51712         No     NaN      0                      +91 8919293202
# 51713        Yes   4.0/5    196    +91 9035808038\r\n+91 9049882302
# 51714         No   3.2/5      4                      +91 8197981979
# 51715         No     NEW      0                      +91 9008787655
# 51716         No     NaN      0                      +91 9632650480
#
#                          location                    rest_type  \
# 0                Old Airport Road                  Quick Bites
# 1                    Brigade Road  Microbrewery, Casual Dining
# 2                  CV Raman Nagar                  Quick Bites
# 3                    Malleshwaram                       Lounge
# 4                             BTM           Takeaway, Delivery
# 5                    Kammanahalli           Takeaway, Delivery
# 6           Koramangala 4th Block                          Bar
# 7                    Shanti Nagar                  Quick Bites
# 8                       Jayanagar                Casual Dining
# 9                        JP Nagar   Beverage Shop, Quick Bites
# 10                      Bellandur       Bakery, Dessert Parlor
# 11          Koramangala 1st Block                  Quick Bites
# 12                            BTM                  Quick Bites
# 13                       JP Nagar                  Quick Bites
# 14                      Jayanagar                Casual Dining
# 15          Koramangala 5th Block   Beverage Shop, Quick Bites
# 16                    Indiranagar                Casual Dining
# 17     ITPL Main Road, Whitefield                  Quick Bites
# 18                            HSR                  Quick Bites
# 19                            BTM                  Quick Bites
# 20          Koramangala 7th Block           Bar, Casual Dining
# 21                            BTM                  Quick Bites
# 22                   New BEL Road                Casual Dining
# 23                      Bellandur                Casual Dining
# 24                     Whitefield                          Bar
# 25          Koramangala 3rd Block                Casual Dining
# 26                Electronic City                        Kiosk
# 27                  Richmond Road                  Quick Bites
# 28                   Kammanahalli                  Quick Bites
# 29                Cunningham Road                  Quick Bites
# ...                           ...                          ...
# 51687                 Koramangala                     Delivery
# 51688             South Bangalore                     Delivery
# 51689                   Jayanagar                  Quick Bites
# 51690                   Bellandur                  Quick Bites
# 51691            Old Airport Road                          Bar
# 51692       Koramangala 7th Block                  Quick Bites
# 51693       Koramangala 6th Block                          Bar
# 51694       Koramangala 6th Block                Casual Dining
# 51695                Lavelle Road            Pub, Microbrewery
# 51696                 Brookefield                  Quick Bites
# 51697                 Brookefield                  Quick Bites
# 51698            Old Airport Road                  Fine Dining
# 51699                    JP Nagar                  Quick Bites
# 51700       Koramangala 5th Block                  Quick Bites
# 51701                  Whitefield                  Quick Bites
# 51702                         BTM                         Mess
# 51703                 Indiranagar                  Quick Bites
# 51704                   Banaswadi                     Delivery
# 51705           Commercial Street                Casual Dining
# 51706           Bannerghatta Road                Casual Dining
# 51707       Koramangala 5th Block                Casual Dining
# 51708       Koramangala 5th Block                         Cafe
# 51709                   Jayanagar               Dessert Parlor
# 51710                     MG Road                         Cafe
# 51711       Koramangala 5th Block                Casual Dining
# 51712                         BTM                  Quick Bites
# 51713                     MG Road                  Lounge, Bar
# 51714                Shanti Nagar          Quick Bites, Bakery
# 51715                         BTM                  Quick Bites
# 51716                Shivajinagar                         Mess
#
#                                               dish_liked  \
# 0                                                    NaN
# 1      Cocktails, Mocktails, Pizza, Sweet Yogurt, Juj...
# 2                                                    NaN
# 3      Beer, Cocktails, Pork Chilli, Pandi Curry, Ste...
# 4                                                    NaN
# 5                                                    NaN
# 6      Beer, Biryani, Cocktails, Masala Peanuts, Chic...
# 7                                                    NaN
# 8      Veg Thali, Matka Kulfi, Pongal, Buttermilk, Va...
# 9                                                    NaN
# 10                                        Designer Cakes
# 11                                                   NaN
# 12                                                   NaN
# 13                                              Shawarma
# 14     Khubani Ka Meetha, Mutton Biryani, Chicken Bir...
# 15                                  Sandwiches, Sandwich
# 16     Noodles, Drunken Chicken Wings, Sweet Corn Sou...
# 17     Pane Pizza, Garlic Bread, Thin Crust Pizza, Pa...
# 18                                                   NaN
# 19                                                   NaN
# 20                                Murgh Ghee Roast, Beer
# 21                                                   NaN
# 22                                                   NaN
# 23                                                   NaN
# 24                                                   NaN
# 25     Chicken Biryani, Chicken Wings, Chicken Curry,...
# 26     Whole Meat Shawarma, Wheat Shawarma, Pita Brea...
# 27                                                   NaN
# 28                                                   NaN
# 29     Burgers, Crispy Chicken, Chicken Zinger Burger...
# ...                                                  ...
# 51687  Halwa, Chicken Biryani, Butter Chicken, Kheer,...
# 51688                                                NaN
# 51689                                                NaN
# 51690                                                NaN
# 51691                            Cocktails, Draught Beer
# 51692                                                NaN
# 51693                                                NaN
# 51694                                                NaN
# 51695  Wheat Beer, Pizza, Cocktails, Virgin Sangria, ...
# 51696                           Fish, Veg Thali, Biryani
# 51697  French Fries, Whole Meat Shawarma, Chicken Sha...
# 51698           Fish Chilli, Tea, Lamb, Thai Wok Chicken
# 51699                                                NaN
# 51700                                                NaN
# 51701                                                NaN
# 51702  Beef Fry, Masala Dosa, Chicken Curry, Fish Fry...
# 51703  Tacos, Nachos, Tikka Masala Burrito, Chicken Q...
# 51704                                      Roti, Noodles
# 51705                                            Biryani
# 51706                                                NaN
# 51707                                    Courteous Staff
# 51708  Salads, Chicken Sandwich, Spaghetti, Arugula S...
# 51709  Rolls, Ice Cream Roll, Paan Ice Cream, Coffee,...
# 51710                                                NaN
# 51711  Chicken Boneless Biryani, Egg Curry, Andhra Bi...
# 51712                                                NaN
# 51713    Cocktails, Mai Thai, Pizza, Lemon Basil Chicken
# 51714                                                NaN
# 51715                                                NaN
# 51716                                                NaN
#
#                                                 cuisines  \
# 0                                                Chinese
# 1             Asian, Continental, European, North Indian
# 2           South Indian, North Indian, Chinese, Biryani
# 3                        Italian, American, North Indian
# 4                                           South Indian
# 5                                  North Indian, Biryani
# 6                     Finger Food, North Indian, Chinese
# 7                                         Biryani, Kebab
# 8                                           South Indian
# 9                                            Drinks Only
# 10                                      Bakery, Desserts
# 11                    Mangalorean, Chinese, North Indian
# 12                                 North Indian, Chinese
# 13                                     Juices, Fast Food
# 14                        North Indian, Biryani, Chinese
# 15                                     Juices, Fast Food
# 16                                               Chinese
# 17                                      Pizza, Fast Food
# 18                                          North Indian
# 19                        North Indian, Chinese, Biryani
# 20                             South Indian, Finger Food
# 21                                           Street Food
# 22                                          North Indian
# 23                                          North Indian
# 24                                           Continental
# 25                                 North Indian, Chinese
# 26                                               Arabian
# 27                                          South Indian
# 28                                          South Indian
# 29                                     Burger, Fast Food
# ...                                                  ...
# 51687                              North Indian, Chinese
# 51688                                             Burger
# 51689                              South Indian, Chinese
# 51690                                Desserts, Ice Cream
# 51691                               Chinese, Continental
# 51692                              North Indian, Chinese
# 51693                           Finger Food, Continental
# 51694                         South Indian, North Indian
# 51695                      Continental, BBQ, Finger Food
# 51696                     Bengali, North Indian, Chinese
# 51697                                            Arabian
# 51698                               Chinese, Thai, Asian
# 51699                      Healthy Food, Beverages, Cafe
# 51700                     Biryani, Chinese, North Indian
# 51701                                            Chinese
# 51702                      Kerala, South Indian, Biryani
# 51703                       Mexican, American, Fast Food
# 51704   North Indian, South Indian, Chinese, Continental
# 51705               North Indian, Fast Food, Street Food
# 51706                              North Indian, Chinese
# 51707                              North Indian, Chinese
# 51708     Cafe, Healthy Food, Salad, Beverages, Desserts
# 51709  Desserts, Ice Cream, Beverages, Fast Food, San...
# 51710                                 Cafe, Healthy Food
# 51711             Biryani, Seafood, Andhra, North Indian
# 51712                              South Indian, Chinese
# 51713               North Indian, Mediterranean, Chinese
# 51714             Chinese, Continental, Desserts, Bakery
# 51715                              South Indian, Chinese
# 51716                                       South Indian
#
#       approx_cost(for two people)  \
# 0                             400
# 1                           1,500
# 2                             450
# 3                           1,400
# 4                             250
# 5                             450
# 6                           1,200
# 7                             250
# 8                             400
# 9                             100
# 10                            300
# 11                            300
# 12                            200
# 13                            150
# 14                            800
# 15                            150
# 16                            650
# 17                            750
# 18                            300
# 19                            300
# 20                          1,000
# 21                            150
# 22                            500
# 23                            500
# 24                          1,500
# 25                            500
# 26                            300
# 27                            300
# 28                            150
# 29                            400
# ...                           ...
# 51687                         300
# 51688                         750
# 51689                         300
# 51690                         250
# 51691                       1,800
# 51692                         300
# 51693                       1,000
# 51694                         400
# 51695                       1,700
# 51696                         400
# 51697                         300
# 51698                       1,900
# 51699                         300
# 51700                         250
# 51701                         200
# 51702                         300
# 51703                         600
# 51704                         450
# 51705                         800
# 51706                         600
# 51707                       1,000
# 51708                       1,200
# 51709                         500
# 51710                         800
# 51711                         600
# 51712                         300
# 51713                       3,000
# 51714                         300
# 51715                         150
# 51716                         100
#
#                                             reviews_list  \
# 0      [('Rated 3.0', 'RATED\n  Ordered the veg combo...
# 1      [('Rated 5.0', "RATED\n  Wow. This was my reac...
# 2      [('Rated 5.0', "RATED\n  Very tasty food...lov...
# 3      [('Rated 3.0', 'RATED\n  As expected the place...
# 4      [('Rated 3.0', "RATED\n  For today's breakfast...
# 5                                                     []
# 6      [('Rated 5.0', 'RATED\n  Ordered lunch from zo...
# 7                                                     []
# 8      [('Rated 5.0', "RATED\n  Located in Jayanagar ...
# 9                                                     []
# 10     [('Rated 4.0', "RATED\n  To start with.. were ...
# 11     [('Rated 3.0', 'RATED\n  Taste -4/5\nbut quant...
# 12     [('Rated 4.0', 'RATED\n  The place is good if ...
# 13     [('Rated 1.0', 'RATED\n  Ordered Mosambi Juice...
# 14     [('Rated 3.0', "RATED\n  Located on main road ...
# 15     [('Rated 5.0', 'RATED\n  All time favourite af...
# 16     [('Rated 4.0', 'RATED\n  I have been visiting ...
# 17     [('Rated 4.0', "RATED\n  Lovely pizza there, M...
# 18     [('Rated 5.0', 'RATED\n  liked it'), ('Rated 3...
# 19     [('Rated 5.0', "RATED\n  Recommended for a hom...
# 20     [('Rated 4.0', 'RATED\n  We recently visited t...
# 21     [('Rated 2.0', "RATED\n  The menu looks very i...
# 22     [('Rated 4.0', 'RATED\n  Awesome food... Worth...
# 23     [('Rated 3.0', 'RATED\n  A very small pocket f...
# 24     [('Rated 5.0', "RATED\n  Food and service are ...
# 25     [('Rated 1.0', 'RATED\n  I have been waiting f...
# 26     [('Rated 2.0', "RATED\n  To be honest, I loved...
# 27                                                    []
# 28     [('Rated 1.0', "RATED\n  Pathetic.... Don't ev...
# 29     [('Rated 5.0', 'RATED\n  KFC is always KFC, de...
# ...                                                  ...
# 51687  [('Rated 1.0', 'RATED\n  Ordered 3 plates. Pat...
# 51688  [('Rated 5.0', 'RATED\n  Burger was yummy , ju...
# 51689                                                 []
# 51690  [('Rated 5.0', 'RATED\n  please maintain the s...
# 51691  [('Rated 5.0', 'RATED\n  Best place to be here...
# 51692                                                 []
# 51693  [('Rated 2.0', "RATED\n  Bad experience!\n\nHa...
# 51694  [('Rated 3.0', 'RATED\n  Service was very good...
# 51695  [('Rated 4.0', "RATED\n  The thing I enjoyed m...
# 51696  [('Rated 4.0', 'RATED\n  One of my favourite b...
# 51697  [('Rated 3.0', 'RATED\n  Tried couple of times...
# 51698  [('Rated 4.0', 'RATED\n  Lovely decor and good...
# 51699                                                 []
# 51700  [('Rated 4.0', 'RATED\n  Food was delicious.\n...
# 51701                                                 []
# 51702  [('Rated 5.0', 'RATED\n  Been eating here sinc...
# 51703  [('Rated 4.0', "RATED\n  Good place for Mexica...
# 51704  [('Rated 4.0', 'RATED\n  A recent favourite fo...
# 51705  [('Rated 2.0', 'RATED\n  We were two people or...
# 51706  [('Rated 4.0', "RATED\n  Sells amazing comfort...
# 51707  [('Rated 5.0', 'RATED\n  Today ladies lunch ge...
# 51708  [('Rated 4.0', 'RATED\n  In totally love with ...
# 51709  [('Rated 4.0', "RATED\n  This place is the bes...
# 51710  [('Rated 3.0', "RATED\n  The moment you enter ...
# 51711  [('Rated 4.0', 'RATED\n  Chicken lollipop?\nCh...
# 51712  [('Rated 1.0', 'RATED\n  Unable to accept the ...
# 51713  [('Rated 4.0', 'RATED\n  The food was awesome....
# 51714  [('Rated 3.0', 'RATED\n  A hangout place for s...
# 51715                                                 []
# 51716                                                 []
#
#                                                menu_item     listed_in(type)  \
# 0                                                     []            Delivery
# 1                                                     []  Drinks & nightlife
# 2                                                     []            Delivery
# 3                                                     []  Drinks & nightlife
# 4      ['Masala Dosa', 'Mini Poori Masala & Bajji', '...            Delivery
# 5                                                     []            Delivery
# 6      ['Chicken 65', 'Chicken Chilly', 'Chicken Lemo...            Delivery
# 7                                                     []            Delivery
# 8                                                     []            Delivery
# 9                                                     []            Delivery
# 10     ['Eggless Pineapple Delight Cake', 'Eggless Bu...            Desserts
# 11     ['Chicken Fried Rice', 'Boiled Rice Meal', 'Ch...            Dine-out
# 12                                                    []            Delivery
# 13     ['Oreo Shake', 'Veg Maggi', 'Egg Maggi', 'Brea...            Delivery
# 14                                                    []            Delivery
# 15                                                    []            Delivery
# 16                                                    []            Delivery
# 17                                                    []            Delivery
# 18                                                    []            Delivery
# 19                                                    []            Dine-out
# 20                                                    []       Pubs and bars
# 21                                                    []            Delivery
# 22                                                    []            Dine-out
# 23                                                    []            Delivery
# 24                                                    []            Dine-out
# 25                                                    []            Dine-out
# 26                                                    []            Dine-out
# 27                                                    []            Dine-out
# 28                                                    []            Delivery
# 29     ['Hot & Crispy', 'Boneless Strips', '4 Pc Hot ...            Delivery
# ...                                                  ...                 ...
# 51687  ['Mughlai Chicken Dum Biryani', 'Chicken Noodl...            Delivery
# 51688                                                 []            Delivery
# 51689  ['Ragi Muddhe Meal', 'Chapati Meal', 'Paratha ...            Delivery
# 51690                                                 []            Delivery
# 51691                                                 []       Pubs and bars
# 51692                                                 []            Delivery
# 51693                                                 []  Drinks & nightlife
# 51694                                                 []            Dine-out
# 51695                                                 []            Delivery
# 51696  ['Veg Thali', 'Veg Special Thali', 'Egg Thali'...            Dine-out
# 51697  ['J.S. Shawarma', 'Whole Meat Shawarma', 'Malg...            Delivery
# 51698                                                 []            Delivery
# 51699                                                 []            Dine-out
# 51700                                                 []            Delivery
# 51701                                                 []            Dine-out
# 51702                                                 []            Delivery
# 51703  ['Veg Tacos', 'Chicken Taco', 'Cheesy Double D...            Dine-out
# 51704  ['Indian Peri Peri French Fries', 'Dinepost9 K...            Delivery
# 51705                                                 []            Dine-out
# 51706                                                 []            Delivery
# 51707                                                 []            Dine-out
# 51708                                                 []            Dine-out
# 51709                                                 []            Delivery
# 51710  ['Pav with Veggie Bhaji', 'Six Grain Paratha',...            Desserts
# 51711  ['Boneless Chilli Chicken', 'Chicken 65', 'Lem...            Dine-out
# 51712                                                 []            Delivery
# 51713                                                 []       Pubs and bars
# 51714                                                 []            Delivery
# 51715                                                 []            Delivery
# 51716                                                 []            Dine-out
#
#              listed_in(city)
# 0           Old Airport Road
# 1             Residency Road
# 2           Old Airport Road
# 3               Malleshwaram
# 4      Koramangala 4th Block
# 5               Kalyan Nagar
# 6      Koramangala 6th Block
# 7              Church Street
# 8                   JP Nagar
# 9          Bannerghatta Road
# 10             Sarjapur Road
# 11     Koramangala 4th Block
# 12     Koramangala 6th Block
# 13                  JP Nagar
# 14                 Jayanagar
# 15                       BTM
# 16               Indiranagar
# 17                Whitefield
# 18                       BTM
# 19     Koramangala 7th Block
# 20     Koramangala 7th Block
# 21                       BTM
# 22              New BEL Road
# 23              Marathahalli
# 24                Whitefield
# 25     Koramangala 5th Block
# 26           Electronic City
# 27                   MG Road
# 28              Kammanahalli
# 29               Frazer Town
# ...                      ...
# 51687              Jayanagar
# 51688                    HSR
# 51689               JP Nagar
# 51690          Sarjapur Road
# 51691       Old Airport Road
# 51692  Koramangala 6th Block
# 51693  Koramangala 7th Block
# 51694  Koramangala 6th Block
# 51695          Church Street
# 51696            Brookefield
# 51697           Marathahalli
# 51698            Indiranagar
# 51699      Bannerghatta Road
# 51700                    BTM
# 51701             Whitefield
# 51702  Koramangala 4th Block
# 51703            Indiranagar
# 51704           Kammanahalli
# 51705           Lavelle Road
# 51706      Bannerghatta Road
# 51707                    BTM
# 51708  Koramangala 5th Block
# 51709           Basavanagudi
# 51710           Lavelle Road
# 51711                    BTM
# 51712  Koramangala 7th Block
# 51713           Brigade Road
# 51714           Basavanagudi
# 51715              Jayanagar
# 51716            Frazer Town
#
# [51717 rows x 17 columns]

# %%
print(len(set(zomato['url'])))
print(len(set(zomato['name'])))
print(len(set(zomato['phone'])))
print(zomato['rate'].value_counts())
# Out:
# 51717
# 8792
# 14927
# NEW       2208
# 3.9/5     2098
# 3.8/5     2022
# 3.7/5     2011
# 3.9 /5    1874
# 3.8 /5    1851
# 3.7 /5    1810
# 3.6/5     1773
# 4.0/5     1609
# 4.0 /5    1574
# 3.6 /5    1543
# 4.1/5     1474
# 4.1 /5    1474
# 3.5/5     1431
# 3.5 /5    1353
# 3.4/5     1259
# 3.4 /5    1217
# 3.3/5     1168
# 4.2 /5    1165
# 3.3 /5    1142
# 4.2/5     1019
# 3.2/5     1006
# 4.3 /5     917
# 3.2 /5     867
# 3.1/5      862
# 4.3/5      776
# 3.1 /5     699
# 4.4 /5     628
# 3.0/5      558
# 4.4/5      519
#           ...
# 2.8/5      313
# 2.8 /5     287
# 4.5/5      247
# 4.6 /5     175
# 2.7/5      170
# 2.6/5      143
# 2.7 /5     137
# 4.6/5      125
# 2.6 /5     117
# 4.7 /5      86
# 4.7/5       81
# -           69
# 2.5 /5      56
# 2.5/5       45
# 4.8 /5      43
# 2.4/5       40
# 4.9 /5      30
# 2.4 /5      30
# 2.3/5       28
# 4.9/5       25
# 4.8/5       23
# 2.3 /5      23
# 2.2/5       19
# 2.1 /5      13
# 2.1/5       11
# 2.2 /5       7
# 2.0 /5       7
# 2.0/5        4
# 1.8 /5       3
# 1.8/5        2
# Name: rate, Length: 64, dtype: int64

# %% [markdown]
# ## A feleslegesnek vélt attribútumok eldobása

# %%
zomato = zomato.drop(['url',  'phone', 'location', 'rest_type', 'reviews_list', 'menu_item'], axis=1)

# %% [markdown]
# ## Az adatbázis tanító és teszt szettekre felbontása

# %%
import hashlib
import numpy as np

def split_train_test_by_id(data, test_ratio, id_column, hash=hashlib.md5):
 ids = data[id_column]
 in_test_set = ids.apply(lambda id_: test_set_check(id_, test_ratio, hash))
 return data.loc[~in_test_set], data.loc[in_test_set]

def test_set_check(identifier, test_ratio, hash):
 return hash(np.int64(identifier)).digest()[-1] < 256 * test_ratio

# %% [markdown]
# ## Szöveges oszlopok átalakítására való függvények

# %%
from sklearn.preprocessing import LabelEncoder

def yesNoConverter(column):
    encoder = LabelEncoder()
    column_converted = encoder.fit_transform(column)
    return column_converted

# %%
def label_factorize(df):
    for col in df.columns[~df.columns.isin(['rate', 'approx_cost(for two people)', 'votes', 'listed_in(type)', 'listed_in(city)'])]:
        df[col] = df[col].factorize()[0]
    return df

# %%
from sklearn.preprocessing import OneHotEncoder

def one_hotTransformer(zomato_encoded):
    encoder = OneHotEncoder(categories='auto')
    zomato_cat_1hot = encoder.fit_transform(zomato_encoded.reshape(-1,1))
    return zomato_cat_1hot

# %%
type_labels = list()
city_labels = list()

def labelEncoder(column, city):
    global type_labels
    global city_labels
    encoder = LabelEncoder()
    zomato_cat_encoded = encoder.fit_transform(column)
    if city:
        city_labels = list(encoder.classes_)
    else:
        type_labels = list(encoder.classes_)
    
    return zomato_cat_encoded

# %% [markdown]
# ## A 'rate' oszlop megtisztítására való függvény

# %% [markdown]
# Eredetileg '4.1 / 5', 'NEW', '-', '3.5/5' formákban találhatóak az adatok.
# Ezekből csak az első tag kellene, a szöveges információkat pedig nan értékekkel helyettesítjük.

# %%
import string

 
def isfloat(value):
  try:
    float(value)
    return True
  except ValueError:
    return False

def cleanRates(data):
    if(isinstance(data, float)):
        return data
    else:
        cleanData = data.translate({ord(c): None for c in string.whitespace})
        vote = cleanData.split('/')
        if (isfloat(vote[0])):
            return float(vote[0])
        else:
            return np.nan

# %% [markdown]
# ## Medián kiszámítására használatos függvény

# %% [markdown]
# Minden olyan adatot, amit később fel kell használni a teszt szettel való műveletek során, egy-egy globális dictionary-be mentjük el.
# Az egyes oszlopokhoz tartozó értékek az oszlop neve alapján érthetőek el (ez a kulcs).

# %%
def calculateMedianByColumnName(column, column_name):
    items_cleaned = []
    numpy_array = np.array(column)
    for x in numpy_array:
        if not np.isnan(x):
            items_cleaned.append(x)
            
    global median      
    median[column_name] = np.median(items_cleaned)
    return median[column_name]

# %%
# csak inicializálás, hogy meglegyenek globálisan
median = dict()

def replaceNanByMedian(column, column_name, training):
    if training:
        global median
        median[column_name] = calculateMedianByColumnName(column, column_name)
        
    column_cleaned = []
    numpy_array = np.array(column)
    for x in numpy_array:
        if np.isnan(x):
            column_cleaned.append(median[column_name])
        else:
            column_cleaned.append(x)
    return column_cleaned

# %% [markdown]
# ## Standard és MinMax skálázó

# %%
# csak inicializálás, hogy meglegyenek globálisan
mean = dict()
variance = dict()

def standardScaler(column, column_name, training):
    if training:
        global mean
        mean[column_name] = np.mean(column)
        global variance
        variance[column_name] = np.var(column)
        
    standardizedCol = []
    for x in column:
        standardizedCol.append((x - mean[column_name]) / variance[column_name])
   
    return standardizedCol

# %%
# csak inicializálás, hogy meglegyenek globálisan
min_value = dict()
max_value = dict()

def Normalize(column, column_name, training):
    if training:
        global min_value
        min_value[column_name] = float(column.min())
        global max_value
        max_value[column_name] = float(column.max())
        
    column_substract = []
    for x in column:
        column_substract.append((float(x)-min_value[column_name])/(max_value[column_name]-min_value[column_name]))
    return column_substract

# %% [markdown]
# ### Apróbb függvény, ami a tizedesvesszőt tartalmazó számadatokból kiveszi a tizedesvesszőt. (Tizedesvesszővel string formátumban vannak)

# %%
def ConvertFromMoneyToString(column):
    column_converted = []
    for x in column:
        if not isfloat(x):
            x = x.replace(",", "")
            column_converted.append(float(x))
        else:
            column_converted.append(float(x))
    return column_converted

# %% [markdown]
# ## Az eredmények megjelenítéséért felelős függvények

# %%
def display_scores(scores):
    print("Scores:", scores)
    print("Mean:", scores.mean())
    print("Standard deviation:", scores.std())
    print("\n")

# %%
def displayLinRegPredictions(lin_reg, train_set_ready_df, labels_ready):
    some_data = train_set_ready_df.iloc[:5]
    #some_data = train_set.iloc[:5]
    some_labels = pd.DataFrame(data=labels_ready).iloc[:5]

    print("Predictions:\t", lin_reg.predict(train_set_ready_df.iloc[:5]))
    print("Labels:\t\t", some_labels)
    print("\n")

# %%
statistic_table = pd.DataFrame()

def printToStatistics(name, rmse, details, pg, mean='Nan', sd='NaN'):
    global statistic_table 
    statistic_table = statistic_table.append({'name' : name , 
                                              'rmse' : rmse , 
                                              'details' : details,
                                              'mean' : mean,
                                              'standard deviation' : sd,
                                              'purging' : pg
                                             } , ignore_index=True)

# %% [markdown]
# ## Saját pipeline egy függvény formájában

# %% [markdown]
# A szükséges helyeken a hiányzó értékeket -1-ekkel töltjük fel, mert ez adta a legjobb eredményt.
# A paraméterben megadható skálázóval skálázzuk a megfelelő attribútumokat az adat "megtisztítása" után (pl. string --> float).
# Némely paraméterre OneHot kódolót is használunk, mert így sikerült a legjobb eredményt elérni.
# Miután minden paramétert feldolgoztunk, egy mátrixot rakunk össze a paraméterekből.

# %%
# csak hogy globális legyen
zomato_labels =  []

def runPipeline(dataset, training, scaler):
    dataset_ready = dataset.copy()
    
    dataset_ready = label_factorize(dataset_ready)
    #dataset_ready = dataset_ready.drop(['rate'], axis=1).fillna(-1) #filling nan values by -1
    dataset_ready['name'] = dataset_ready['name'].fillna(-1)
    dataset_ready['cuisines'] = dataset_ready['cuisines'].fillna(-1)
    dataset_ready['dish_liked'] = dataset_ready['dish_liked'].fillna(-1)
    dataset_ready['address'] = dataset_ready['address'].fillna(-1)
    
    dataset_ready['online_order'] = yesNoConverter(dataset_ready['online_order'])
    dataset_ready['book_table'] = yesNoConverter(dataset_ready['book_table'])
    
    dataset_type_encoded = labelEncoder(dataset_ready['listed_in(type)'], False)
    dataset_type_encoded_oneHot = one_hotTransformer(dataset_type_encoded)
        
    dataset_city_encoded = labelEncoder(dataset_ready['listed_in(city)'], True)
    dataset_city_encoded_oneHot = one_hotTransformer(dataset_city_encoded)
    
    dataset_ready['approx_cost(for two people)'] = ConvertFromMoneyToString(dataset_ready['approx_cost(for two people)'])
    dataset_ready['approx_cost(for two people)'] = replaceNanByMedian(dataset_ready['approx_cost(for two people)'], "approx_cost(for two people)", training)
    dataset_ready['approx_cost(for two people)'] = scaler(dataset_ready['approx_cost(for two people)'], "approx_cost(for two people)", training)
    dataset_ready['name'] = scaler(dataset_ready['name'], "name", training)
    dataset_ready['address'] = scaler(dataset_ready['address'], "address", training)
    dataset_ready['dish_liked'] = scaler(dataset_ready['dish_liked'], "dish_liked", training)
    dataset_ready['cuisines'] = scaler(dataset_ready['cuisines'], "cuisines", training)
    dataset_ready['votes'] = scaler(dataset_ready['votes'], "votes", training)
    dataset_num = dataset_ready.drop(['listed_in(type)', 'listed_in(city)', 'rate'], axis=1)
    dataset_ready = np.concatenate((np.concatenate((dataset_num, dataset_type_encoded_oneHot.toarray()), axis=1), dataset_city_encoded_oneHot.toarray()), axis=1)
    return dataset_ready

# %% [markdown]
# ## Az adat betanítása, majd a betanított adatbázison futtatása a modelleknek

# %% [markdown]
# Nem ad vissza adatot, futás közben az összes modellel produkált eredményt sorban kiírja.

# %%
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import cross_val_score
from sklearn.metrics import mean_squared_error
from sklearn.linear_model import LinearRegression

def trainDataWithGivenScalerAndRunAllModels(dataset, labels, scaler, details, purging):
    dataset_ready = runPipeline(dataset, True, scaler)
    dataset_ready_df = pd.DataFrame(dataset_ready)
    
    # Lineáris regresszió    
    lin_reg = LinearRegression()
    lin_reg.fit(dataset_ready, labels)
    train_set_predictions = lin_reg.predict(dataset_ready_df)
    lin_mse = mean_squared_error(labels, train_set_predictions)
    lin_rmse = np.sqrt(lin_mse)
    printToStatistics('LinearRegression', lin_rmse, details, purging, lin_rmse)
    print("Linear Regression with", details)
    displayLinRegPredictions(lin_reg, dataset_ready_df, labels)
    
    # Döntési fa
    tree_reg = DecisionTreeRegressor()
    tree_reg.fit(dataset_ready, labels)
    train_set_predictions = tree_reg.predict(dataset_ready_df)
    tree_mse = mean_squared_error(labels, train_set_predictions)
    tree_rmse = np.sqrt(tree_mse)
    decision_tree_scores = cross_val_score(tree_reg, dataset_ready_df, labels, scoring="neg_mean_squared_error", cv=10)
    tree_rmse_scores = np.sqrt(-decision_tree_scores)
    printToStatistics('DecisionTreeRegressor', tree_rmse, details, purging, tree_rmse_scores.mean(), tree_rmse_scores.std())
    print("Decision Tree with", details)
    display_scores(tree_rmse_scores)
    
    # Random forest
    forest_reg = RandomForestRegressor(10)
    forest_reg.fit(dataset_ready_df, pd.DataFrame(data=labels).values.ravel())
    train_set_predictions = forest_reg.predict(dataset_ready_df)
    forest_mse = mean_squared_error(labels, train_set_predictions)
    forest_rmse = np.sqrt(forest_mse)
    forest_scores = cross_val_score(forest_reg, dataset_ready_df, pd.DataFrame(data=labels).values.ravel(), scoring="neg_mean_squared_error", cv=10)
    forest_rmse_scores = np.sqrt(-forest_scores)
    printToStatistics('RandomForestRegressor', forest_rmse, details, purging, forest_rmse_scores.mean(), forest_rmse_scores.std())
    print("Random forest with", details)
    display_scores(forest_rmse_scores)

# %% [markdown]
# ## Az adatbázis kezdeti feldolgozása

# %% [markdown]
# Cél attribútum üres értéket tartalmazó sorokat eldobjuk (ehhez előbb szükséges az értékelések átalakítása nekünk megfelelő (4.1/5 --> 4.1) formába).
# Majd tanító és teszt szettekre bontása.

# %%
import seaborn as sns

#MAIN
dataset = zomato.copy()
cleaned_rate_labels = []
        
dataset = dataset.loc[dataset['rate'] !='NEW']
dataset = dataset.loc[dataset['rate'] !='-'].reset_index(drop=True)

for n in dataset['rate']:
    cleaned_rate_labels.append(float(cleanRates(n)))
dataset['rate'] = cleaned_rate_labels
dataset = dataset.drop(dataset[np.isnan(dataset['rate'])].index)

dataset = dataset.reset_index()

train_set, test_set = split_train_test_by_id(dataset, 0.2, "index")

train_labels = train_set['rate']
train_set = train_set.drop('index', axis=1)
test_labels = test_set['rate']
test_set = test_set.drop('index', axis=1)

# %% [markdown]
# ## A modellek kipróbálása mindkét skálázóval

# %%
print("Running Models with MinMax")
trainDataWithGivenScalerAndRunAllModels(train_set, train_labels, Normalize, "MinMaxNorm with Basic Data", "No")

print("Running Models with StandardScaler")
trainDataWithGivenScalerAndRunAllModels(train_set, train_labels, standardScaler, "StandardScaler with Basic Data", "No")
# Out:
# Running Models with MinMax
# Linear Regression with MinMaxNorm with Basic Data
# Predictions:	 [3.55755615 3.94094849 3.55874634 3.75488281 4.04022217]
# Labels:		    rate
# 0   3.9
# 1   4.4
# 2   3.2
# 3   4.0
# 5   3.9
#
#
# Decision Tree with MinMaxNorm with Basic Data
# Scores: [0.18754254 0.20558829 0.19476373 0.18879139 0.19603196 0.20003777
#  0.19554575 0.18975736 0.2059261  0.19720777]
# Mean: 0.19611926628783144
# Standard deviation: 0.006101490520291016
#
#
# Random forest with MinMaxNorm with Basic Data
# Scores: [0.16586576 0.16181905 0.17239149 0.16118733 0.16573918 0.16680952
#  0.16246654 0.16844102 0.16332476 0.15676418]
# Mean: 0.16448088285889623
# Standard deviation: 0.004123819523465152
#
#
# Running Models with StandardScaler
# Linear Regression with StandardScaler with Basic Data
# Predictions:	 [3.55743724 3.9408331  3.55863501 3.75478066 4.04032755]
# Labels:		    rate
# 0   3.9
# 1   4.4
# 2   3.2
# 3   4.0
# 5   3.9
#
#
# Decision Tree with StandardScaler with Basic Data
# Scores: [0.19109321 0.20336397 0.19581601 0.19136702 0.19117742 0.20097225
#  0.19408759 0.19161164 0.20095721 0.19636313]
# Mean: 0.19568094513844614
# Standard deviation: 0.0044089283383138495
#
#
# Random forest with StandardScaler with Basic Data
# Scores: [0.16491433 0.16146934 0.17444485 0.15951119 0.16833505 0.16571785
#  0.16287924 0.16391285 0.15811264 0.1537694 ]
# Mean: 0.16330667417344125
# Standard deviation: 0.005422278683857389

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
ax = statistic_table.plot.hist(bins=12, alpha=0.5)

# %% [markdown]
# ## A 'votes' oszlopból a kiugró értékek helyettesítése az általunk megadott maximum értékkel, majd a modellek ismételt futtatása a 'purgált' adatbázissal

# %%
#PURGÁLÁS
zomato_with_id = zomato.reset_index()
purged_dataset = dataset.copy()
#purged_dataset = dataset.drop(dataset[dataset["votes"] > 5000].index)
purged_dataset["votes"].where(purged_dataset["votes"] < 5000, 5000, inplace=True)
print(purged_dataset.shape)
purged_dataset = purged_dataset.reset_index()

second_train_set, second_test_set = split_train_test_by_id(purged_dataset, 0.2, "index")
second_train_labels = second_train_set['rate']
second_train_set = second_train_set.drop('index', axis=1)
second_test_labels = second_test_set['rate']
second_test_set = second_test_set.drop('index', axis=1)

print("Running Models with MinMax")
trainDataWithGivenScalerAndRunAllModels(second_train_set, second_train_labels,  Normalize, "MinMaxNorm with Purged Data", "Yes")

print("Running Models with StandardScaler")
trainDataWithGivenScalerAndRunAllModels(second_train_set, second_train_labels, standardScaler, "StandardScaler  with Purged Data", "Yes")
# Out:
# (41665, 12)
# Running Models with MinMax
# Linear Regression with MinMaxNorm with Purged Data
# Predictions:	 [3.5542059  3.91665906 3.55347399 3.77450758 4.03206541]
# Labels:		    rate
# 0   3.9
# 1   4.4
# 2   3.2
# 3   4.0
# 5   3.9
#
#
# Decision Tree with MinMaxNorm with Purged Data
# Scores: [0.23844917 0.27944058 0.19905337 0.20415745 0.20463797 0.20080677
#  0.20537504 0.19990176 0.21255543 0.21005259]
# Mean: 0.21544301330152943
# Standard deviation: 0.023942041405519712
#
#
# Random forest with MinMaxNorm with Purged Data
# Scores: [0.18632663 0.18068529 0.17921305 0.1725513  0.17380321 0.18284983
#  0.17179628 0.17491474 0.17132331 0.17327878]
# Mean: 0.1766742409073291
# Standard deviation: 0.00496118909551174
#
#
# Running Models with StandardScaler
# Linear Regression with StandardScaler  with Purged Data
# Predictions:	 [3.5542059  3.91665907 3.55347399 3.77450756 4.03206542]
# Labels:		    rate
# 0   3.9
# 1   4.4
# 2   3.2
# 3   4.0
# 5   3.9
#
#
# Decision Tree with StandardScaler  with Purged Data
# Scores: [0.23804973 0.25940164 0.19944771 0.20208942 0.20226132 0.20624871
#  0.1993113  0.20191737 0.2148323  0.20949074]
# Mean: 0.2133050236439244
# Standard deviation: 0.01889220160073189
#
#
# Random forest with StandardScaler  with Purged Data
# Scores: [0.19446138 0.18194253 0.18138624 0.1694136  0.17127118 0.17546975
#  0.17032847 0.17950353 0.1681122  0.18801302]
# Mean: 0.17799018823677568
# Standard deviation: 0.008261560763664784

# %% [markdown]
# ## Feldolgozott (fit hívás) adatbázisok elmentése későbbi használatra

# %%
train_set_ready_with_minmax = runPipeline(train_set, True, Normalize)

train_set_ready_with_standard_scaler = runPipeline(train_set, True, standardScaler)

# %%
print(train_set_ready_with_minmax.shape)
print(train_set_ready_with_minmax)
# Out:
# (33091, 45)
# [[0.00000000e+00 0.00000000e+00 0.00000000e+00 ... 0.00000000e+00
#   0.00000000e+00 0.00000000e+00]
#  [1.17702448e-04 1.55255395e-04 1.00000000e+00 ... 1.00000000e+00
#   0.00000000e+00 0.00000000e+00]
#  [2.35404896e-04 3.10510790e-04 0.00000000e+00 ... 0.00000000e+00
#   0.00000000e+00 0.00000000e+00]
#  ...
#  [5.06120527e-02 6.53625213e-02 0.00000000e+00 ... 0.00000000e+00
#   0.00000000e+00 0.00000000e+00]
#  [2.35404896e-03 5.34078559e-02 1.00000000e+00 ... 0.00000000e+00
#   0.00000000e+00 0.00000000e+00]
#  [1.94209040e-02 2.53066294e-02 0.00000000e+00 ... 0.00000000e+00
#   0.00000000e+00 0.00000000e+00]]

# %%
statistic_table
# Out:
#                              details      mean                   name purging  \
# 0         MinMaxNorm with Basic Data  0.345683       LinearRegression      No
# 1         MinMaxNorm with Basic Data  0.196119  DecisionTreeRegressor      No
# 2         MinMaxNorm with Basic Data  0.164481  RandomForestRegressor      No
# 3     StandardScaler with Basic Data  0.345683       LinearRegression      No
# 4     StandardScaler with Basic Data  0.195681  DecisionTreeRegressor      No
# 5     StandardScaler with Basic Data  0.163307  RandomForestRegressor      No
# 6        MinMaxNorm with Purged Data  0.342844       LinearRegression     Yes
# 7        MinMaxNorm with Purged Data  0.215443  DecisionTreeRegressor     Yes
# 8        MinMaxNorm with Purged Data  0.176674  RandomForestRegressor     Yes
# 9   StandardScaler  with Purged Data  0.342844       LinearRegression     Yes
# 10  StandardScaler  with Purged Data  0.213305  DecisionTreeRegressor     Yes
# 11  StandardScaler  with Purged Data  0.177990  RandomForestRegressor     Yes
#
#             rmse standard deviation
# 0   3.456835e-01                NaN
# 1   5.691556e-16         0.00610149
# 2   6.778588e-02         0.00412382
# 3   3.456835e-01                NaN
# 4   5.689462e-16         0.00440893
# 5   6.590382e-02         0.00542228
# 6   3.428436e-01                NaN
# 7   5.673254e-16           0.023942
# 8   7.282903e-02         0.00496119
# 9   3.428436e-01                NaN
# 10  5.671678e-16          0.0188922
# 11  7.164759e-02         0.00826156

# %% [markdown]
# ## Cross Validation futtatása a legjobb modellel

# %%
from sklearn.model_selection import GridSearchCV
param_grid = [
     {'bootstrap': [False], 'n_estimators': [10, 15, 20], 'max_features': [3, 5, 10]},
 ]
forest_reg = RandomForestRegressor()
grid_search = GridSearchCV(forest_reg, param_grid, cv=10, scoring='neg_mean_squared_error')
grid_search.fit(train_set_ready_with_standard_scaler, train_labels)
# Out:
# GridSearchCV(cv=10, error_score='raise-deprecating',
#        estimator=RandomForestRegressor(bootstrap=True, criterion='mse', max_depth=None,
#            max_features='auto', max_leaf_nodes=None,
#            min_impurity_decrease=0.0, min_impurity_split=None,
#            min_samples_leaf=1, min_samples_split=2,
#            min_weight_fraction_leaf=0.0, n_estimators='warn', n_jobs=None,
#            oob_score=False, random_state=None, verbose=0, warm_start=False),
#        fit_params=None, iid='warn', n_jobs=None,
#        param_grid=[{'bootstrap': [False], 'n_estimators': [10, 15, 20], 'max_features': [3, 5, 10]}],
#        pre_dispatch='2*n_jobs', refit=True, return_train_score='warn',
#        scoring='neg_mean_squared_error', verbose=0)

# %%
print(grid_search.best_params_)
print(grid_search.best_estimator_)
# Out:
# {'bootstrap': False, 'max_features': 10, 'n_estimators': 20}
# RandomForestRegressor(bootstrap=False, criterion='mse', max_depth=None,
#            max_features=10, max_leaf_nodes=None, min_impurity_decrease=0.0,
#            min_impurity_split=None, min_samples_leaf=1,
#            min_samples_split=2, min_weight_fraction_leaf=0.0,
#            n_estimators=20, n_jobs=None, oob_score=False,
#            random_state=None, verbose=0, warm_start=False)

# %%
cvres = grid_search.cv_results_
for mean_score, params in zip(cvres["mean_test_score"], cvres["params"]):
    print(np.sqrt(-mean_score), params)
print('min: ', np.sqrt(-cvres["mean_test_score"].max()))
# Out:
# 0.26338777850690986 {'bootstrap': False, 'max_features': 3, 'n_estimators': 10}
# 0.2625528700719186 {'bootstrap': False, 'max_features': 3, 'n_estimators': 15}
# 0.2587130447672507 {'bootstrap': False, 'max_features': 3, 'n_estimators': 20}
# 0.2187645745343939 {'bootstrap': False, 'max_features': 5, 'n_estimators': 10}
# 0.2109279040499965 {'bootstrap': False, 'max_features': 5, 'n_estimators': 15}
# 0.20901666376058206 {'bootstrap': False, 'max_features': 5, 'n_estimators': 20}
# 0.1640402539615405 {'bootstrap': False, 'max_features': 10, 'n_estimators': 10}
# 0.15802114051536867 {'bootstrap': False, 'max_features': 10, 'n_estimators': 15}
# 0.15374898668476134 {'bootstrap': False, 'max_features': 10, 'n_estimators': 20}
# min:  0.15374898668476134

# %%
#from sklearn.model_selection import RandomizedSearchCV
#forest_reg = RandomForestRegressor()
#from scipy.stats import randint as sp_randint
#param_dist = {
 #             "max_features": sp_randint(2, 45),
  #            "bootstrap": [True, False],
  #            'n_estimators': sp_randint(3, 10)}
#n_iter_search = 10
#rand_search = RandomizedSearchCV(forest_reg,param_distributions=param_dist, n_iter=n_iter_search, cv=10, scoring='neg_mean_squared_error')
#rand_search.fit(train_set_ready_with_minmax, train_labels)

# %% [markdown]
# ## Csak a vizualizáció kedvéért újra lefuttatás

# %%
best_predictions = grid_search.best_estimator_.predict(train_set_ready_with_standard_scaler)
abs_error_array = abs(best_predictions - train_labels)

# %%
plt.figure(figsize=(6,6))
sns.distplot(abs_error_array)
plt.show()

# %%
best_estimator_scores_ = cross_val_score(grid_search.best_estimator_, train_set_ready_with_standard_scaler, train_labels, scoring="neg_mean_squared_error", cv=10)
best_estimator_scores = np.sqrt(-best_estimator_scores_)

# %%
plt.figure(figsize=(6,6))
sns.distplot(best_estimator_scores)
plt.show()

# %%
feature_importances = grid_search.best_estimator_.feature_importances_
feature_importances
# Out:
# array([0.08996001, 0.09330801, 0.01363232, 0.06448848, 0.30603245,
#        0.14533142, 0.09572836, 0.10495176, 0.00155089, 0.00228765,
#        0.00425324, 0.00604465, 0.00367337, 0.00109744, 0.00114252,
#        0.00165139, 0.00151419, 0.00269278, 0.00190068, 0.0030092 ,
#        0.00094372, 0.00458756, 0.00096789, 0.0036147 , 0.00109901,
#        0.00281952, 0.00343313, 0.00238817, 0.00166717, 0.00180326,
#        0.00199457, 0.00118015, 0.00107354, 0.00089522, 0.00119185,
#        0.00090844, 0.00110944, 0.00246847, 0.00514174, 0.00225582,
#        0.00308008, 0.00227384, 0.00105751, 0.00378495, 0.00400943])

# %%
def plot_importances(model, cols):
    plt.figure(figsize=(12,6))
    f_imp = pd.Series(model.feature_importances_, index=cols).sort_values(ascending=True)
    f_imp.plot(kind='barh')

# %% [markdown]
# ## Az egyes attribútumok 'fontossága' a predikcióban

# %%
attributes = ['address', 'name', 'online_order', 'book_table', 'votes', 'dish_liked', 'cuisines', 'approx_cost(for two people)'] + type_labels + city_labels
sorted(zip(feature_importances, attributes), reverse=True)
# Out:
# [(0.3060324504616813, 'votes'),
#  (0.14533141583953976, 'dish_liked'),
#  (0.10495176071750008, 'approx_cost(for two people)'),
#  (0.09572836436509899, 'cuisines'),
#  (0.09330801355363494, 'name'),
#  (0.08996001163817108, 'address'),
#  (0.06448847814433567, 'book_table'),
#  (0.013632319757297914, 'online_order'),
#  (0.006044645269737114, 'Desserts'),
#  (0.005141738663355491, 'Marathahalli'),
#  (0.00458756290554964, 'Brookefield'),
#  (0.0042532449704051475, 'Delivery'),
#  (0.004009431348138862, 'Whitefield'),
#  (0.003784954026322021, 'Sarjapur Road'),
#  (0.003673372026015664, 'Dine-out'),
#  (0.003614704082906755, 'Electronic City'),
#  (0.003433127454569915, 'Indiranagar'),
#  (0.0030800797656016575, 'Old Airport Road'),
#  (0.003009195378506152, 'Bellandur'),
#  (0.002819518060063691, 'HSR'),
#  (0.0026927832359750986, 'Bannerghatta Road'),
#  (0.0024684685749355333, 'Malleshwaram'),
#  (0.002388165582707336, 'JP Nagar'),
#  (0.0022876453207724976, 'Cafes'),
#  (0.002273840436589982, 'Rajajinagar'),
#  (0.0022558232385126876, 'New BEL Road'),
#  (0.001994569212567511, 'Kammanahalli'),
#  (0.0019006800630776567, 'Basavanagudi'),
#  (0.001803263432619582, 'Kalyan Nagar'),
#  (0.0016671652229801087, 'Jayanagar'),
#  (0.001651387784982161, 'BTM'),
#  (0.0015508948835211878, 'Buffet'),
#  (0.0015141931191097499, 'Banashankari'),
#  (0.0011918465090180598, 'Koramangala 7th Block'),
#  (0.0011801515331557068, 'Koramangala 4th Block'),
#  (0.0011425159974880763, 'Pubs and bars'),
#  (0.0011094449975480852, 'MG Road'),
#  (0.0010990092365100307, 'Frazer Town'),
#  (0.0010974397579655132, 'Drinks & nightlife'),
#  (0.0010735398102387406, 'Koramangala 5th Block'),
#  (0.0010575112179288142, 'Residency Road'),
#  (0.0009678932730947136, 'Church Street'),
#  (0.000943717520123631, 'Brigade Road'),
#  (0.0009084443589310097, 'Lavelle Road'),
#  (0.0008952172512147009, 'Koramangala 6th Block')]

# %%
plot_importances(grid_search.best_estimator_, attributes)

# %% [markdown]
# ## Végül a teszt szetten futtatás, mérés

# %%
final_model = grid_search.best_estimator_

X_test = runPipeline(test_set, False, standardScaler)
y_test = test_labels

# %%
print(len(y_test))
X_test_df = pd.DataFrame(X_test)
final_predictions = final_model.predict(X_test_df)
final_mse = mean_squared_error(y_test, final_predictions)
final_rmse = np.sqrt(final_mse)
display_scores(final_rmse)
# Out:
# 8574
# Scores: 0.3172925639462793
# Mean: 0.3172925639462793
# Standard deviation: 0.0

# %%
y_test.plot(kind='hist', label='true values')
pd.Series(final_predictions).plot(kind='hist', label='predictions')
plt.legend()

# %% [markdown]
# ## Model vizsgálata, mi alapján dönt a döntési fa

# %%
from sklearn.tree import export_graphviz
from IPython.display import Image
import pydot
def convert_dot_to_png(model, max_depth=5, feature_names=list(attributes)):
    export_graphviz(model.estimators_[0], out_file='tree.dot', max_depth=max_depth, feature_names=feature_names, rounded=True)
    (graph,) = pydot.graph_from_dot_file('tree.dot')
    graph.write_png('tree.png')

# %%
convert_dot_to_png(final_model)
Image('tree.png')

# %% [markdown]
# ## Lokáció (GPS koordináták) hozzáadása

# %%
def generateBaseMap(default_location=[12.97, 77.59], default_zoom_start=12):
    base_map = folium.Map(location=default_location, control_scale=True, zoom_start=default_zoom_start)
    return base_map

# %% [markdown]
# Geopy segítségével a lokációk koordiánátinak lekérése.

# %%
def get_lat_lon(df):
    locations=pd.DataFrame({"Name":zomato['location'].unique()})
    locations['Name']=locations['Name'].apply(lambda x: "Bangalore " + str(x))
    lat=[]
    lon=[]
    geolocator=Nominatim(user_agent="app")
    for location in locations['Name']:
        location = geolocator.geocode(location)
        if location is None:
            lat.append(np.nan)
            lon.append(np.nan)
        else:    
            lat.append(location.latitude)
            lon.append(location.longitude)
    locations['lat']=lat
    locations['lon']=lon
    return locations

# %%
from geopy.geocoders import Nominatim

zomato_loc = backup_zomato.copy()
locations=pd.DataFrame({"Name":zomato_loc['location'].unique()})
locations['Name']=locations['Name'].apply(lambda x: "Bangalore " + str(x))
lat_lon=[]
geolocator=Nominatim(user_agent="app")
for location in locations['Name']:
    location = geolocator.geocode(location)
    if location is None:
        lat_lon.append(np.nan)
    else:    
        geo=(location.latitude,location.longitude)
        lat_lon.append(geo)

locations['geo_loc']=lat_lon

# %%
locations["Name"]=locations['Name'].apply(lambda x :  x.replace("Bangalore","")[1:])
locations.head()
# Out:
#                Name                          geo_loc
# 0  Old Airport Road         (12.9593577, 77.6614182)
# 1      Brigade Road         (12.9736132, 77.6074716)
# 2    CV Raman Nagar                              NaN
# 3      Malleshwaram         (13.0027353, 77.5703253)
# 4               BTM  (12.91127585, 77.6045654343118)

# %%
Rest_locations=pd.DataFrame(zomato_loc['location'].value_counts().reset_index())
Rest_locations.columns=['Name','count']
Rest_locations=Rest_locations.merge(locations,on='Name',how="left").dropna()
Rest_locations['count'].max()
# Out:
# 5124

# %%
from folium.plugins import HeatMap
import folium

lat,lon=zip(*np.array(Rest_locations['geo_loc']))
Rest_locations['lat']=lat
Rest_locations['lon']=lon
basemap=generateBaseMap()
HeatMap(Rest_locations[['lat','lon','count']].values.tolist(),zoom=20,radius=15).add_to(basemap)

# %%
basemap
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# A helyek összepárosítása a gps koordinátákkal.

# %%
loc_dict = dict(zip(zomato_loc['location'].unique(), locations['geo_loc']))
loc_array = list()
for x in zomato_loc['location']:
    loc_array.append(loc_dict[x])

# %% [markdown]
# NaN értékek lecserélése (-1, -1)-ekre a gps koordinátáknál.

# %%
nan_free_loc_array = []
for x in loc_array:
    if(x != x):
        nan_free_loc_array.append((-1, -1))
    else:
        nan_free_loc_array.append(x)

# %% [markdown]
# ## Új dataset létrehozása, azon szokásos feldolgozás elvégzése

# %%
extended_dataset = zomato.copy()
cleaned_rate_labels = []

list_of_lat = [x[0] for x in nan_free_loc_array]
list_of_lon = [x[1] for x in nan_free_loc_array]

extended_dataset['lat'] = list_of_lat
extended_dataset['lon'] = list_of_lon

extended_dataset = extended_dataset.loc[extended_dataset['rate'] !='NEW']
extended_dataset = extended_dataset.loc[extended_dataset['rate'] !='-'].reset_index(drop=True)

for n in extended_dataset['rate']:
    cleaned_rate_labels.append(float(cleanRates(n)))
extended_dataset['rate'] = cleaned_rate_labels
extended_dataset = extended_dataset.drop(extended_dataset[np.isnan(extended_dataset['rate'])].index)

extended_dataset = extended_dataset.reset_index()

extended_train_set, extended_test_set = split_train_test_by_id(extended_dataset, 0.2, "index")

extended_train_labels = extended_train_set['rate']
extended_train_set = extended_train_set.drop('index', axis=1)
extended_test_labels = extended_test_set['rate']
extended_test_set = extended_test_set.drop('index', axis=1)

# %% [markdown]
# Az új attribútumok skálázása külön, hiszen ez előtt meghívva nem léteznek még, így a függvényben nem kivitelezhető.
#
# Skálázatlan oszlopok kimentése a későbbi vizualizációra való felhasználásra.

# %%
not_scaled_extended_train_set = pd.DataFrame()
not_scaled_extended_train_set['lat'] = extended_train_set['lat']
not_scaled_extended_train_set['lon'] = extended_train_set['lon']

extended_train_set['lat'] = standardScaler(extended_train_set['lat'], "lat", True)
extended_train_set['lon'] = standardScaler(extended_train_set['lon'], "lon", True)

extended_test_set['lat'] = standardScaler(extended_test_set['lat'], "lat", False)
extended_test_set['lon'] = standardScaler(extended_test_set['lon'], "lon", False)

# %% [markdown]
# A maradék adat végigfuttatása a Pipeline-on, feldolgozott dataset elmentése (extended_train_set_ready_with_standard_scaler).

# %%
trainDataWithGivenScalerAndRunAllModels(extended_train_set, extended_train_labels,  standardScaler, "StandardScaler with Lat Lon Data", "No")
# Out:
# Linear Regression with StandardScaler with Lat Lon Data
# Predictions:	 [3.56534893 3.95014884 3.56574734 3.76297012 4.04377978]
# Labels:		    rate
# 0   3.9
# 1   4.4
# 2   3.2
# 3   4.0
# 5   3.9
#
#
# Decision Tree with StandardScaler with Lat Lon Data
# Scores: [0.17608533 0.18608271 0.18976533 0.17998187 0.19541434 0.19775103
#  0.1842056  0.19386947 0.20299212 0.18846295]
# Mean: 0.18946107438593143
# Standard deviation: 0.007845866584911277
#
#
# Random forest with StandardScaler with Lat Lon Data
# Scores: [0.15787151 0.16018905 0.16369386 0.15634036 0.1624031  0.16492771
#  0.15837552 0.15757301 0.15327531 0.14560178]
# Mean: 0.15802512044995615
# Standard deviation: 0.005326525272847626

# %%
extended_train_set_ready_with_standard_scaler = runPipeline(extended_train_set, True, standardScaler)

# %% [markdown]
# ## GridSearch Cross Validation lefuttatása

# %%
grid_search.fit(extended_train_set_ready_with_standard_scaler, extended_train_labels)
# Out:
# GridSearchCV(cv=10, error_score='raise-deprecating',
#        estimator=RandomForestRegressor(bootstrap=True, criterion='mse', max_depth=None,
#            max_features='auto', max_leaf_nodes=None,
#            min_impurity_decrease=0.0, min_impurity_split=None,
#            min_samples_leaf=1, min_samples_split=2,
#            min_weight_fraction_leaf=0.0, n_estimators='warn', n_jobs=None,
#            oob_score=False, random_state=None, verbose=0, warm_start=False),
#        fit_params=None, iid='warn', n_jobs=None,
#        param_grid=[{'bootstrap': [False], 'n_estimators': [10, 15, 20], 'max_features': [3, 5, 10]}],
#        pre_dispatch='2*n_jobs', refit=True, return_train_score='warn',
#        scoring='neg_mean_squared_error', verbose=0)

# %%
cvres = grid_search.cv_results_
for mean_score, params in zip(cvres["mean_test_score"], cvres["params"]):
    print(np.sqrt(-mean_score), params)
print('min: ', np.sqrt(-cvres["mean_test_score"].max()))
# Out:
# 0.24450479847312465 {'bootstrap': False, 'max_features': 3, 'n_estimators': 10}
# 0.2398349629655886 {'bootstrap': False, 'max_features': 3, 'n_estimators': 15}
# 0.23535670862677274 {'bootstrap': False, 'max_features': 3, 'n_estimators': 20}
# 0.19372082173000302 {'bootstrap': False, 'max_features': 5, 'n_estimators': 10}
# 0.1873847508095507 {'bootstrap': False, 'max_features': 5, 'n_estimators': 15}
# 0.18585854701554827 {'bootstrap': False, 'max_features': 5, 'n_estimators': 20}
# 0.1484042220470581 {'bootstrap': False, 'max_features': 10, 'n_estimators': 10}
# 0.1412138340442663 {'bootstrap': False, 'max_features': 10, 'n_estimators': 15}
# 0.14086192954388488 {'bootstrap': False, 'max_features': 10, 'n_estimators': 20}
# min:  0.14086192954388488

# %% [markdown]
# ## A legjobb becslő általi eredmények megjelenítése

# %%
best_predictions = grid_search.best_estimator_.predict(extended_train_set_ready_with_standard_scaler)

# %%
best_estimator_scores_ = cross_val_score(grid_search.best_estimator_, extended_train_set_ready_with_standard_scaler, extended_train_labels, scoring="neg_mean_squared_error", cv=10)
best_estimator_scores = np.sqrt(-best_estimator_scores_)
best_estimator_scores
# Out:
# array([0.13625577, 0.14923578, 0.15245342, 0.13769269, 0.14895934,
#        0.14865845, 0.13585102, 0.14547717, 0.13276163, 0.13502487])

# %%
plt.figure(figsize=(6,6))
sns.distplot(best_estimator_scores)
plt.show()

# %%
attributes = ['address', 'name', 'online_order', 'book_table', 'votes', 'dish_liked', 'cuisines', 'approx_cost(for two people)', 'lat', 'lot'] + type_labels + city_labels
sorted(zip(feature_importances, attributes), reverse=True)
# Out:
# [(0.3060324504616813, 'votes'),
#  (0.14533141583953976, 'dish_liked'),
#  (0.10495176071750008, 'approx_cost(for two people)'),
#  (0.09572836436509899, 'cuisines'),
#  (0.09330801355363494, 'name'),
#  (0.08996001163817108, 'address'),
#  (0.06448847814433567, 'book_table'),
#  (0.013632319757297914, 'online_order'),
#  (0.006044645269737114, 'Cafes'),
#  (0.005141738663355491, 'MG Road'),
#  (0.00458756290554964, 'Bellandur'),
#  (0.0042532449704051475, 'Buffet'),
#  (0.004009431348138862, 'Residency Road'),
#  (0.003784954026322021, 'Rajajinagar'),
#  (0.003673372026015664, 'Delivery'),
#  (0.003614704082906755, 'Brookefield'),
#  (0.003433127454569915, 'Frazer Town'),
#  (0.0030800797656016575, 'Marathahalli'),
#  (0.003009195378506152, 'Bannerghatta Road'),
#  (0.002819518060063691, 'Electronic City'),
#  (0.0026927832359750986, 'BTM'),
#  (0.0024684685749355333, 'Lavelle Road'),
#  (0.002388165582707336, 'HSR'),
#  (0.0022876453207724976, 'lot'),
#  (0.002273840436589982, 'New BEL Road'),
#  (0.0022558232385126876, 'Malleshwaram'),
#  (0.001994569212567511, 'Jayanagar'),
#  (0.0019006800630776567, 'Banashankari'),
#  (0.001803263432619582, 'JP Nagar'),
#  (0.0016671652229801087, 'Indiranagar'),
#  (0.001651387784982161, 'Drinks & nightlife'),
#  (0.0015508948835211878, 'lat'),
#  (0.0015141931191097499, 'Pubs and bars'),
#  (0.0011918465090180598, 'Koramangala 5th Block'),
#  (0.0011801515331557068, 'Kalyan Nagar'),
#  (0.0011425159974880763, 'Dine-out'),
#  (0.0011094449975480852, 'Koramangala 7th Block'),
#  (0.0010990092365100307, 'Church Street'),
#  (0.0010974397579655132, 'Desserts'),
#  (0.0010735398102387406, 'Kammanahalli'),
#  (0.0010575112179288142, 'Old Airport Road'),
#  (0.0009678932730947136, 'Brigade Road'),
#  (0.000943717520123631, 'Basavanagudi'),
#  (0.0009084443589310097, 'Koramangala 6th Block'),
#  (0.0008952172512147009, 'Koramangala 4th Block')]

# %% [markdown]
# ## Teszt lefuttatása végül, eredmény kijelzése

# %%
final_model = grid_search.best_estimator_

X_extended_test = runPipeline(extended_test_set, False, standardScaler)
y_extended_test = extended_test_labels
print(len(y_test))
X_extended_test_df = pd.DataFrame(X_extended_test)
final_predictions = final_model.predict(X_extended_test_df)
final_mse = mean_squared_error(y_extended_test, final_predictions)
final_rmse = np.sqrt(final_mse)
display_scores(final_rmse)
y_extended_test.plot(kind='hist', label='true values')
pd.Series(final_predictions).plot(kind='hist', label='predictions')
plt.legend()
# Out:
# 8574
# Scores: 0.3238329636330656
# Mean: 0.3238329636330656
# Standard deviation: 0.0

# %% [markdown]
# ## K-Means klaszterezéssel GPS koordináták csoportokba sorolása

# %% [markdown]
# Az előbb elmentett "extended_train_set" felhasználása (ez csak a 'lat' és 'lon' oszlopokat tartalmazza)

# %%
coord_cols_train_df = pd.DataFrame()
coord_cols_train_df['lat'] = extended_train_set['lat']
coord_cols_train_df['lon'] = extended_train_set['lon']

# %%
coord_cols_train = np.array(coord_cols_train_df)

# %% [markdown]
# ### Klaszterezés lefuttatása

# %%
from sklearn.cluster import KMeans

km = KMeans()
y_km = km.fit_predict(coord_cols_train)

# %% [markdown]
# ## Új dataset létrehozása, azon szokásos feldolgozás elvégzése

# %%
dataset_with_zones = zomato.copy()
cleaned_rate_labels = []

dataset_with_zones = dataset_with_zones.loc[dataset_with_zones['rate'] !='NEW']
dataset_with_zones = dataset_with_zones.loc[dataset_with_zones['rate'] !='-'].reset_index(drop=True)

for n in dataset_with_zones['rate']:
    cleaned_rate_labels.append(float(cleanRates(n)))
dataset_with_zones['rate'] = cleaned_rate_labels
dataset_with_zones = dataset_with_zones.drop(dataset_with_zones[np.isnan(dataset_with_zones['rate'])].index)

dataset_with_zones = dataset_with_zones.reset_index()

zones_train_set, zones_test_set = split_train_test_by_id(dataset_with_zones, 0.2, "index")

zones_train_labels = zones_train_set['rate']
zones_train_set = zones_train_set.drop('index', axis=1)
zones_train_set['zone'] = y_km
zones_test_labels = zones_test_set['rate']
zones_test_set = zones_test_set.drop('index', axis=1)

# %%
trainDataWithGivenScalerAndRunAllModels(zones_train_set, zones_train_labels,  standardScaler, "StandardScaler with Zones Data", "No")
# Out:
# Linear Regression with StandardScaler with Zones Data
# Predictions:	 [3.55206174 3.93623865 3.56810676 3.75440328 4.03552896]
# Labels:		    rate
# 0   3.9
# 1   4.4
# 2   3.2
# 3   4.0
# 5   3.9
#
#
# Decision Tree with StandardScaler with Zones Data
# Scores: [0.18740557 0.20547802 0.19166683 0.17907286 0.19710047 0.20387601
#  0.1988711  0.18931889 0.19933404 0.18908729]
# Mean: 0.19412110740518287
# Standard deviation: 0.007802072425357859
#
#
# Random forest with StandardScaler with Zones Data
# Scores: [0.15551794 0.16505592 0.17033095 0.15493543 0.16595175 0.16099992
#  0.1588974  0.16574502 0.15323883 0.15124066]
# Mean: 0.1601913815667551
# Standard deviation: 0.006088897820279393

# %% [markdown]
# Az adatok végigfuttatása a Pipeline-on, feldolgozott dataset elmentése (zones_train_set_ready_with_standard_scaler).

# %%
zones_train_set_ready_with_standard_scaler = runPipeline(zones_train_set, True, standardScaler)

# %% [markdown]
# ## GridSearch Cross Validation lefuttatása

# %%
grid_search.fit(zones_train_set_ready_with_standard_scaler, zones_train_labels)
# Out:
# GridSearchCV(cv=10, error_score='raise-deprecating',
#        estimator=RandomForestRegressor(bootstrap=True, criterion='mse', max_depth=None,
#            max_features='auto', max_leaf_nodes=None,
#            min_impurity_decrease=0.0, min_impurity_split=None,
#            min_samples_leaf=1, min_samples_split=2,
#            min_weight_fraction_leaf=0.0, n_estimators='warn', n_jobs=None,
#            oob_score=False, random_state=None, verbose=0, warm_start=False),
#        fit_params=None, iid='warn', n_jobs=None,
#        param_grid=[{'bootstrap': [False], 'n_estimators': [10, 15, 20], 'max_features': [3, 5, 10]}],
#        pre_dispatch='2*n_jobs', refit=True, return_train_score='warn',
#        scoring='neg_mean_squared_error', verbose=0)

# %%
cvres = grid_search.cv_results_
for mean_score, params in zip(cvres["mean_test_score"], cvres["params"]):
    print(np.sqrt(-mean_score), params)
print('min: ', np.sqrt(-cvres["mean_test_score"].max()))
# Out:
# 0.25762121630942525 {'bootstrap': False, 'max_features': 3, 'n_estimators': 10}
# 0.25112265130035105 {'bootstrap': False, 'max_features': 3, 'n_estimators': 15}
# 0.2469667804435521 {'bootstrap': False, 'max_features': 3, 'n_estimators': 20}
# 0.2084967161265467 {'bootstrap': False, 'max_features': 5, 'n_estimators': 10}
# 0.20239506885510708 {'bootstrap': False, 'max_features': 5, 'n_estimators': 15}
# 0.1985073108436371 {'bootstrap': False, 'max_features': 5, 'n_estimators': 20}
# 0.15548719713143558 {'bootstrap': False, 'max_features': 10, 'n_estimators': 10}
# 0.15218356465424968 {'bootstrap': False, 'max_features': 10, 'n_estimators': 15}
# 0.14720074872188849 {'bootstrap': False, 'max_features': 10, 'n_estimators': 20}
# min:  0.14720074872188849

# %% [markdown]
# ## A legjobb becslő általi eredmények megjelenítése

# %%
best_predictions = grid_search.best_estimator_.predict(zones_train_set_ready_with_standard_scaler)

# %%
best_estimator_scores_ = cross_val_score(grid_search.best_estimator_, zones_train_set_ready_with_standard_scaler, zones_train_labels, scoring="neg_mean_squared_error", cv=10)
best_estimator_scores = np.sqrt(-best_estimator_scores_)
best_estimator_scores
# Out:
# array([0.14544465, 0.15200896, 0.16088028, 0.15131655, 0.15274035,
#        0.15016766, 0.15378525, 0.14945327, 0.14009328, 0.13812559])

# %%
plt.figure(figsize=(6,6))
sns.distplot(best_estimator_scores)
plt.show()

# %%
attributes = ['address', 'name', 'online_order', 'book_table', 'votes', 'dish_liked', 'cuisines', 'approx_cost(for two people)', 'zones'] + type_labels + city_labels
sorted(zip(feature_importances, attributes), reverse=True)
# Out:
# [(0.3060324504616813, 'votes'),
#  (0.14533141583953976, 'dish_liked'),
#  (0.10495176071750008, 'approx_cost(for two people)'),
#  (0.09572836436509899, 'cuisines'),
#  (0.09330801355363494, 'name'),
#  (0.08996001163817108, 'address'),
#  (0.06448847814433567, 'book_table'),
#  (0.013632319757297914, 'online_order'),
#  (0.006044645269737114, 'Delivery'),
#  (0.005141738663355491, 'Malleshwaram'),
#  (0.00458756290554964, 'Brigade Road'),
#  (0.0042532449704051475, 'Cafes'),
#  (0.004009431348138862, 'Sarjapur Road'),
#  (0.003784954026322021, 'Residency Road'),
#  (0.003673372026015664, 'Desserts'),
#  (0.003614704082906755, 'Church Street'),
#  (0.003433127454569915, 'HSR'),
#  (0.0030800797656016575, 'New BEL Road'),
#  (0.003009195378506152, 'Basavanagudi'),
#  (0.002819518060063691, 'Frazer Town'),
#  (0.0026927832359750986, 'Banashankari'),
#  (0.0024684685749355333, 'MG Road'),
#  (0.002388165582707336, 'Indiranagar'),
#  (0.0022876453207724976, 'Buffet'),
#  (0.002273840436589982, 'Old Airport Road'),
#  (0.0022558232385126876, 'Marathahalli'),
#  (0.001994569212567511, 'Kalyan Nagar'),
#  (0.0019006800630776567, 'Bannerghatta Road'),
#  (0.001803263432619582, 'Jayanagar'),
#  (0.0016671652229801087, 'JP Nagar'),
#  (0.001651387784982161, 'Pubs and bars'),
#  (0.0015508948835211878, 'zones'),
#  (0.0015141931191097499, 'BTM'),
#  (0.0011918465090180598, 'Koramangala 6th Block'),
#  (0.0011801515331557068, 'Kammanahalli'),
#  (0.0011425159974880763, 'Drinks & nightlife'),
#  (0.0011094449975480852, 'Lavelle Road'),
#  (0.0010990092365100307, 'Electronic City'),
#  (0.0010974397579655132, 'Dine-out'),
#  (0.0010735398102387406, 'Koramangala 4th Block'),
#  (0.0010575112179288142, 'Rajajinagar'),
#  (0.0009678932730947136, 'Brookefield'),
#  (0.000943717520123631, 'Bellandur'),
#  (0.0009084443589310097, 'Koramangala 7th Block'),
#  (0.0008952172512147009, 'Koramangala 5th Block')]

# %% [markdown]
# ## K-Means klaszterezés ellenőrzése

# %%
X_loc = coord_cols_train.copy()
y_loc = y_km.copy()

# %% [markdown]
# Először a tanító szettet is szétszedjük és azon is ellenőrzünk a K Nearest Neighbors klaszterezés segítségével.

# %%
from sklearn.model_selection import train_test_split  
X_loc_train, X_loc_test, y_loc_train, y_loc_test = train_test_split(X_loc, y_loc, test_size=0.20)

# %%
from sklearn.neighbors import KNeighborsClassifier  
classifier = KNeighborsClassifier(n_neighbors=8)  
classifier.fit(X_loc_train, y_loc_train)
# Out:
# KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#            metric_params=None, n_jobs=None, n_neighbors=8, p=2,
#            weights='uniform')

# %%
y_pred = classifier.predict(X_loc_test)

# %% [markdown]
# Amint látni, 100%-ig egyeznek a prediktált értékek.

# %%
from sklearn.metrics import classification_report, confusion_matrix  
print(confusion_matrix(y_loc_test, y_pred))  
print(classification_report(y_loc_test, y_pred))
# Out:
# [[1582    0    0    0    0    0    0    0]
#  [   0  145    0    0    0    0    0    0]
#  [   0    0  786    0    0    0    0    0]
#  [   0    0    0 2012    0    0    0    0]
#  [   0    0    0    0  519    0    0    0]
#  [   0    0    0    0    0  611    0    0]
#  [   0    0    0    0    0    0  228    0]
#  [   0    0    0    0    0    0    0  736]]
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00      1582
#            1       1.00      1.00      1.00       145
#            2       1.00      1.00      1.00       786
#            3       1.00      1.00      1.00      2012
#            4       1.00      1.00      1.00       519
#            5       1.00      1.00      1.00       611
#            6       1.00      1.00      1.00       228
#            7       1.00      1.00      1.00       736
#
#    micro avg       1.00      1.00      1.00      6619
#    macro avg       1.00      1.00      1.00      6619
# weighted avg       1.00      1.00      1.00      6619

# %% [markdown]
# Majd a teszt szetten is megjósoljuk a kategóriákat és hozzáadjuk a teszt szetthez az oszlopot.

# %%
coord_cols_test_df = pd.DataFrame()
coord_cols_test_df['lat'] = extended_test_set['lat']
coord_cols_test_df['lon'] = extended_test_set['lon']
coord_cols_test = np.array(coord_cols_test_df)


y_test_pred = classifier.predict(coord_cols_test)

# %%
zones_test_set['zones'] = y_test_pred

# %% [markdown]
# ## Teszt lefuttatása végül, eredmény kijelzése

# %%
final_model = grid_search.best_estimator_

X_zones_test = runPipeline(zones_test_set, False, standardScaler)
y_zones_test = zones_test_labels
print(len(y_test))
X_zones_test_df = pd.DataFrame(X_zones_test)
final_predictions = final_model.predict(X_zones_test_df)
final_mse = mean_squared_error(y_zones_test, final_predictions)
final_rmse = np.sqrt(final_mse)
display_scores(final_rmse)
y_zones_test.plot(kind='hist', label='true values')
pd.Series(final_predictions).plot(kind='hist', label='predictions')
plt.legend()
# Out:
# 8574
# Scores: 0.31988542075553095
# Mean: 0.31988542075553095
# Standard deviation: 0.0

# %%
statistic_table.sort_values(by=['mean'])
# Out:
#                              details      mean                   name purging  \
# 14  StandardScaler with Lat Lon Data  0.158025  RandomForestRegressor      No
# 17    StandardScaler with Zones Data  0.160191  RandomForestRegressor      No
# 5     StandardScaler with Basic Data  0.163307  RandomForestRegressor      No
# 2         MinMaxNorm with Basic Data  0.164481  RandomForestRegressor      No
# 8        MinMaxNorm with Purged Data  0.176674  RandomForestRegressor     Yes
# 11  StandardScaler  with Purged Data  0.177990  RandomForestRegressor     Yes
# 13  StandardScaler with Lat Lon Data  0.189461  DecisionTreeRegressor      No
# 16    StandardScaler with Zones Data  0.194121  DecisionTreeRegressor      No
# 4     StandardScaler with Basic Data  0.195681  DecisionTreeRegressor      No
# 1         MinMaxNorm with Basic Data  0.196119  DecisionTreeRegressor      No
# 10  StandardScaler  with Purged Data  0.213305  DecisionTreeRegressor     Yes
# 7        MinMaxNorm with Purged Data  0.215443  DecisionTreeRegressor     Yes
# 6        MinMaxNorm with Purged Data  0.342844       LinearRegression     Yes
# 9   StandardScaler  with Purged Data  0.342844       LinearRegression     Yes
# 15    StandardScaler with Zones Data  0.345530       LinearRegression      No
# 12  StandardScaler with Lat Lon Data  0.345643       LinearRegression      No
# 0         MinMaxNorm with Basic Data  0.345683       LinearRegression      No
# 3     StandardScaler with Basic Data  0.345683       LinearRegression      No
#
#             rmse standard deviation
# 14  6.558731e-02         0.00532653
# 17  6.711122e-02          0.0060889
# 5   6.590382e-02         0.00542228
# 2   6.778588e-02         0.00412382
# 8   7.282903e-02         0.00496119
# 11  7.164759e-02         0.00826156
# 13  6.048827e-16         0.00784587
# 16  5.884568e-16         0.00780207
# 4   5.689462e-16         0.00440893
# 1   5.691556e-16         0.00610149
# 10  5.671678e-16          0.0188922
# 7   5.673254e-16           0.023942
# 6   3.428436e-01                NaN
# 9   3.428436e-01                NaN
# 15  3.455303e-01                NaN
# 12  3.456426e-01                NaN
# 0   3.456835e-01                NaN
# 3   3.456835e-01                NaN

# %%
coord_cols_df = pd.DataFrame()
coord_cols_df['lat'] = not_scaled_extended_train_set['lat']
coord_cols_df['lon'] = not_scaled_extended_train_set['lon']
coord_cols_ = np.array(coord_cols_df)

# %% [markdown]
# Kiszedjük a -1-es sorokat, hogy meg tudjuk állapítani a legkisebb értékeket, amikkel körbehatárolhatjuk a térképet a vizualizációnál.

# %%
coord_cols_del = [x for x in coord_cols_ if x[0] != -1.0]

# %%
lower_lat = min(coord_cols_del, key = lambda t: t[1])[1] 
lower_lon = min(coord_cols_del, key = lambda t: t[0])[0]
upper_lat = max(coord_cols_del, key = lambda t: t[1])[1]
upper_lon = max(coord_cols_del, key = lambda t: t[0])[0]

# %%
print(lower_lat)
print(lower_lon)
print(upper_lat)
print(upper_lon)
# Out:
# 77.4333346
# 12.9055682
# 77.7519261
# 13.3457317

# %% [markdown]
# Kiszedjük az egyedi értékeket (először tuple formába konvertáljuk, hogy megmaradjanak az adatkettesek), a hozzájuk tartozó "zónákkal" párban.

# %%
tuple_coords = []
for x in coord_cols_:
    tuple_coords.append((x[0], x[1]))
unique_tuple_coords = np.unique(tuple_coords, return_index = True, axis = 0)   
unique_y_km = []
for x in unique_tuple_coords[1]:
    unique_y_km.append(y_km[x])

# %% [markdown]
# Kirajzoltatjuk az egyedi koordinátákat (hiszen nem lehet/ nincs értelme ugyanazt a pontot többször), különböző zónákat különböző színnel.
# Itt viszont az eredeti koordinátákat kell felhasználnunk, hiszen a skálázott értékekkel nem lehet jól vizualizálni.

# %%
from mpl_toolkits.basemap import Basemap

m=Basemap(llcrnrlon = lower_lon - 0.1, llcrnrlat = lower_lat - 0.1, urcrnrlon = upper_lon + 0.1 , urcrnrlat = upper_lat + 0.1)
m.drawmapboundary(fill_color='#A6CAE0', linewidth=0)
m.fillcontinents(color='grey', alpha=0.7, lake_color='grey')
m.drawcoastlines(linewidth=0.1, color="white")

for coord, zona in zip(unique_tuple_coords[0], unique_y_km):
    if zona == 0:
        m.plot(coord[0], coord[1], linestyle='none', marker="o", markersize=16, alpha=0.6, c="black", markeredgecolor="black", markeredgewidth=1)
    if zona == 1:
        m.plot(coord[0], coord[1], linestyle='none', marker="o", markersize=16, alpha=0.6, c="orange", markeredgecolor="black", markeredgewidth=1)
    if zona == 2:
        m.plot(coord[0], coord[1], linestyle='none', marker="o", markersize=16, alpha=0.6, c="red", markeredgecolor="black", markeredgewidth=1)
    if zona == 3:
        m.plot(coord[0], coord[1], linestyle='none', marker="o", markersize=16, alpha=0.6, c="yellow", markeredgecolor="black", markeredgewidth=1)
    if zona == 4:
        m.plot(coord[0], coord[1], linestyle='none', marker="o", markersize=16, alpha=0.6, c="blue", markeredgecolor="black", markeredgewidth=1)
    if zona == 5:
        m.plot(coord[0], coord[1], linestyle='none', marker="o", markersize=16, alpha=0.6, c="green", markeredgecolor="black", markeredgewidth=1)
    if zona == 6:
        m.plot(coord[0], coord[1], linestyle='none', marker="o", markersize=16, alpha=0.6, c="brown", markeredgecolor="black", markeredgewidth=1)
    if zona == 7:
        m.plot(coord[0], coord[1], linestyle='none', marker="o", markersize=16, alpha=0.6, c="purple", markeredgecolor="black", markeredgewidth=1)

# %%
from collections import Counter
Counter(unique_y_km)
# Out:
# Counter({1: 1, 0: 9, 7: 9, 5: 10, 3: 26, 4: 12, 6: 10, 2: 2})
