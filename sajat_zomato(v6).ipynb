# %% [markdown]
# ## Adatok beolvasása

# %%
import pandas as pd
import os
def load_data(path):
 csv_path = os.path.join(path, "zomato.csv")
 return pd.read_csv(csv_path)

zomato = load_data("datasets")

# %% [markdown]
# Adatok összekeverése annak érdekében, hogy esetleges mintákat elimináljuk a kezdeti adatbázisban.

# %%
from sklearn.utils import shuffle
zomato = shuffle(zomato)
zomato.reset_index(inplace=True, drop=True)

# %%
backup_zomato = zomato.copy()

# %%
zomato
# Out:
#                                                      url  \
# 0      https://www.zomato.com/bangalore/new-punjabi-h...
# 1      https://www.zomato.com/bangalore/dum-biryani-h...
# 2      https://www.zomato.com/bangalore/juice-junctio...
# 3      https://www.zomato.com/bangalore/20-feet-high-...
# 4      https://www.zomato.com/bangalore/entropy-cafe-...
# 5      https://www.zomato.com/bangalore/tiffanys-shan...
# 6      https://www.zomato.com/bangalore/amar-kolkata-...
# 7      https://www.zomato.com/bangalore/prems-biriyan...
# 8      https://www.zomato.com/bangalore/desi-streat-b...
# 9      https://www.zomato.com/bangalore/caf%C3%A9-fel...
# 10     https://www.zomato.com/bangalore/mainland-chin...
# 11     https://www.zomato.com/bangalore/the-barn-bar-...
# 12     https://www.zomato.com/bangalore/amul-ice-crea...
# 13     https://www.zomato.com/bangalore/xo-belgian-wa...
# 14     https://www.zomato.com/bangalore/tandoor-and-s...
# 15     https://www.zomato.com/bangalore/srinidhi-hote...
# 16     https://www.zomato.com/bangalore/healthy-parat...
# 17     https://www.zomato.com/bangalore/the-chervil-j...
# 18     https://www.zomato.com/bangalore/basaveshwarna...
# 19     https://www.zomato.com/bangalore/thancos-natur...
# 20     https://www.zomato.com/bangalore/sunny-spice-c...
# 21     https://www.zomato.com/bangalore/foodys-lane-k...
# 22     https://www.zomato.com/bangalore/bangalore-hot...
# 23     https://www.zomato.com/bangalore/tgi-fridays-b...
# 24     https://www.zomato.com/bangalore/roti-wala-btm...
# 25     https://www.zomato.com/bangalore/the-open-box-...
# 26     https://www.zomato.com/bangalore/bake-feast-ba...
# 27     https://www.zomato.com/bangalore/sangam-sweets...
# 28     https://www.zomato.com/bangalore/new-sri-udupi...
# 29     https://www.zomato.com/bangalore/dasaprakash-c...
# ...                                                  ...
# 51687  https://www.zomato.com/bangalore/patio-the-res...
# 51688  https://www.zomato.com/bangalore/gobble-up-chu...
# 51689  https://www.zomato.com/bangalore/polar-bear-1-...
# 51690  https://www.zomato.com/bangalore/quality-eat-w...
# 51691  https://www.zomato.com/bangalore/yummrajj-btm-...
# 51692  https://www.zomato.com/bangalore/kaumudis-juoi...
# 51693  https://www.zomato.com/bangalore/sunnys-1-lave...
# 51694  https://www.zomato.com/bangalore/chun-li-koram...
# 51695  https://www.zomato.com/bangalore/five-senses-u...
# 51696  https://www.zomato.com/bangalore/night-restro-...
# 51697  https://www.zomato.com/bangalore/new-agarwal-b...
# 51698  https://www.zomato.com/bangalore/thayee-touch-...
# 51699  https://www.zomato.com/bangalore/the-paratha-s...
# 51714                                                NaN
# 51715  Rice Bowl, Rice Bowls, California Burrito, Bbq...
# 51716  Choco Fudge Brownie, Sandwich, Ice Cream Pizza...
#
#                                                 cuisines  \
# 0                                  North Indian, Chinese
# 1                                                Biryani
# 2                                      Juices, Fast Food
# 3                    American, Continental, Steak, Salad
# 4             Cafe, Chinese, Pizza, North Indian, Burger
# 5                          Continental, Italian, Chinese
# 6                         Bengali, North Indian, Chinese
# 7                                     Biryani, Fast Food
# 8                              South Indian, Street Food
# 9                            American, Cafe, Continental
# 10                                        Chinese, Momos
# 11                       American, North Indian, Chinese
# 12                                   Desserts, Ice Cream
# 13                                   Desserts, Beverages
# 14            North Indian, Chinese, Biryani, Hyderabadi
# 15                        North Indian, Chinese, Biryani
# 16                                          North Indian
# 17                             North Indian, Continental
# 18                                          South Indian
# 19                                   Ice Cream, Desserts
# 20                                Chinese, Thai, Seafood
# 21                                 North Indian, Chinese
# 22                                        Biryani, Kebab
# 23                      American, Burger, Italian, Steak
# 24                                          North Indian
# 25     European, North Indian, Mediterranean, Asian, ...
# 26                                                Bakery
# 27                                   Mithai, Street Food
# 28     North Indian, South Indian, Chinese, Beverages...
# 29                                                  Cafe
# ...                                                  ...
# 51687                  Cafe, Continental, Chinese, Momos
# 51688         Beverages, Cafe, Desserts, Spanish, Bakery
# 51689           Desserts, Ice Cream, Beverages, Sandwich
# 51690                                       South Indian
# 51691                                          Fast Food
# 51692                       Beverages, Fast Food, Juices
# 51693            European, Italian, Seafood, Continental
# 51694                                            Chinese
# 51695               Continental, North Indian, Fast Food
# 51696                              North Indian, Chinese
# 51697         North Indian, Chinese, Street Food, Mithai
# 51698                North Indian, Chinese, South Indian
# 51699                                       North Indian
# 51700                                 Cafe, Healthy Food
# 51701                          North Indian, Street Food
# 51702                North Indian, Chinese, South Indian
# 51703                 Chinese, North Indian, Continental
# 51704                                     Fast Food, Tea
# 51705                 Continental, Chinese, North Indian
# 51706                       North Indian, Chinese, Rolls
# 51707                             Italian, Pizza, Burger
# 51708                                   Bakery, Desserts
# 51709                                   Fast Food, Rolls
# 51710                              Bengali, North Indian
# 51711                                           Desserts
# 51712                      North Indian, Kerala, Chinese
# 51713                                       North Indian
# 51714                South Indian, North Indian, Chinese
# 51715                                 Mexican, Fast Food
# 51716           Desserts, Ice Cream, Beverages, Sandwich
#
#       approx_cost(for two people)  \
# 0                             400
# 1                             700
# 2                             150
# 3                           1,000
# 4                             600
# 5                           1,000
# 6                             300
# 7                             300
# 8                             400
# 9                           1,700
# 10                          1,700
# 11                          1,500
# 12                            100
# 13                            400
# 14                            550
# 15                            140
# 16                            200
# 17                          1,000
# 18                            200
# 19                            450
# 20                            650
# 21                            450
# 22                            200
# 23                          1,700
# 24                            300
# 25                          1,400
# 26                            300
# 27                            200
# 28                            200
# 29                            400
# ...                           ...
# 51687                         500
# 51688                         400
# 51689                         400
# 51690                         400
# 51691                         500
# 51692                         150
# 51693                       2,100
# 51694                         300
# 51695                         500
# 51696                         500
# 51697                         400
# 51698                         450
# 51699                         250
# 51700                         800
# 51701                         300
# 51702                         350
# 51703                         200
# 51704                         200
# 51705                         500
# 51706                         700
# 51707                         450
# 51708                         200
# 51709                         350
# 51710                         300
# 51711                         300
# 51712                         600
# 51713                         700
# 51714                         600
# 51715                         400
# 51716                         400
#
#                                             reviews_list  \
# 0      [('Rated 2.0', 'RATED\n  Not good. Had ordered...
# 1      [('Rated 5.0', 'RATED\n  Paneer biriyani in th...
# 2      [('Rated 4.0', 'RATED\n  Sandwiches here are v...
# 3      [('Rated 3.0', "RATED\n  Good seating area to ...
# 4      [('Rated 4.0', "RATED\n  Ordered a snack bite ...
# 5      [('Rated 2.0', 'RATED\n  Had been visiting the...
# 6      [('Rated 3.0', 'RATED\n  ????????????? ???? ??...
# 7                                                     []
# 8      [('Rated 1.0', "RATED\n  Try asking for combo....
# 9      [('Rated 3.0', 'RATED\n  Ok so I didnÃ\x83Ã\...
# 10     [('Rated 5.0', "RATED\n  The team here, Debnat...
# 11     [('Rated 5.0', 'RATED\n  Wanted to have a few ...
# 12                                                    []
# 13     [('Rated 4.0', 'RATED\n  Sunday indulgence don...
# 14     [('Rated 5.0', 'RATED\n  A restaurant nearby t...
# 15                                                    []
# 16                                                    []
# 17     [('Rated 1.0', 'RATED\n  Food is good but our ...
# 18     [('Rated 5.0', "RATED\n  If you are looking fo...
# 19     [('Rated 4.0', 'RATED\n  First time visit with...
# 20     [('Rated 1.0', 'RATED\n  Thanks for spoiling t...
# 21                                                    []
# 22                                                    []
# 23     [('Rated 3.0', "RATED\n  I've been coming here...
# 24     [('Rated 4.0', 'RATED\n  Well, I never had a c...
# 25     [('Rated 4.0', 'RATED\n  Been here on a weekda...
# 26     [('Rated 1.0', 'RATED\n  Worst quality cakes. ...
# 27     [('Rated 3.0', 'RATED\n  This sangam sweets sh...
# 28                                                    []
# 29     [('Rated 4.0', "RATED\n  Had the filter coffee...
# ...                                                  ...
# 51687  [('Rated 5.0', 'RATED\n  The place has a nice ...
# 51688  [('Rated 4.0', 'RATED\n  Surprised to see an e...
# 51689  [('Rated 4.0', "RATED\n  Polar Bear is one of ...
# 51690                                                 []
# 51691  [('Rated 2.0', 'RATED\n  No doubt this place s...
# 51692  [('Rated 5.0', "RATED\n  Excellent sandwich so...
# 51693  [('Rated 4.0', "RATED\n  One of the finest Ita...
# 51694  [('Rated 2.0', 'RATED\n  There was hardly any ...
# 51695                                                 []
# 51696  [('Rated 4.0', 'RATED\n  Ordered tandoori chic...
# 51697  [('Rated 4.5', 'RATED\n  The staff is really p...
# 51698  [('Rated 4.0', 'RATED\n  They Should mention i...
# 51699  [('Rated 5.0', "RATED\n  Here is a new way to ...
# 51700  [('Rated 3.0', "RATED\n  The moment you enter ...
# 51701  [('Rated 3.0', 'RATED\n  Small basic make shif...
# 51702  [('Rated 3.0', 'RATED\n  Tried chicken biriyan...
# 51703  [('Rated 3.0', 'RATED\n  okish'), ('Rated 2.0'...
# 51704  [('Rated 4.0', 'RATED\n  A very new place open...
# 51705  [('Rated 1.0', 'RATED\n  Ordered leefu fried r...
# 51706                                                 []
# 51707  [('Rated 3.0', 'RATED\n  Expectations were hig...
# 51708  [('Rated 3.0', 'RATED\n  Took a home delivery ...
# 51709  [('Rated 4.0', 'RATED\n  Everyone loves rolls ...
# 51710  [('Rated 5.0', "RATED\n  Excellent food and re...
# 51711  [('Rated 1.0', "RATED\n  Ordered normal waffle...
# 51712  [('Rated 1.0', 'RATED\n  I live very close to ...
# 51713  [('Rated 4.0', 'RATED\n  Decent ambience. The ...
# 51714  [('Rated 5.0', 'RATED\n  Shree udupi grand is ...
# 51715  [('Rated 4.0', 'RATED\n  The place is extremel...
# 51716  [('Rated 4.0', "RATED\n  Polar Bear is one of ...
#
#                                                menu_item listed_in(type)  \
# 0                                                     []        Delivery
# 1                                                     []        Dine-out
# 2                                                     []        Dine-out
# 3      ['Herb Crusted Chicken with Pepper Sauce', 'Ve...        Delivery
# 4                                                     []        Delivery
# 5                                                     []        Dine-out
# 6                                                     []        Delivery
# 7                                                     []        Delivery
# 8      ['Coke [Large]', 'Sprite [Large]', '3 Mini Dos...        Delivery
# 9                                                     []        Delivery
# 10                                                    []        Delivery
# 11                                                    []        Dine-out
# 12                                                    []        Desserts
# 13     ['The Ultimate XÃ\x83Ã\x83Ã\x82Ã\x83Ã\x83...        Delivery
# 14                                                    []        Dine-out
# 15                                                    []        Delivery
# 16                                                    []        Delivery
# 17     ['Tandoori Roti', 'Laccha Paratha', 'Butter Na...        Dine-out
# 18                                                    []        Delivery
# 19                                                    []        Desserts
# 20                                                    []        Dine-out
# 21     ['Dal Khichadi', 'Paneer Biryani', 'Chicken Fr...        Dine-out
# 22                                                    []        Dine-out
# 23                                                    []        Delivery
# 24                                                    []        Delivery
# 25     ['Konkan Fish Curry & Rice', 'Caesar Salad wit...        Delivery
# 26                                                    []        Dine-out
# 27                                                    []        Desserts
# 28                                                    []        Dine-out
# 29                                                    []        Dine-out
# ...                                                  ...             ...
# 51687  ['Veg Steamed Momos', 'Chicken Shanghai Fried ...           Cafes
# 51688                                                 []        Delivery
# 51689  ['Rich Chocolate Ice Cream [1 Scoop]', 'Alphon...        Dine-out
# 51690                                                 []        Delivery
# 51691  ['Chicken Kabab [8 Piece]', 'Boneless Chicken ...        Delivery
# 51692                                                 []        Dine-out
# 51693                                                 []        Delivery
# 51694  ['Chicken Fried Rice', 'Veg Manchurian Noodles...        Delivery
# 51695  ['Millet Khichdi', 'Coromandel Chicken', 'Pepp...        Delivery
# 51696                                                 []        Delivery
# 51697  ['Basundi [1 Cup]', 'Carrot Halwa [100 Grams]'...        Delivery
# 51698                                                 []        Dine-out
# 51699  ['Gajar Ka Halwa', 'Aloo Paratha Chole Combo',...        Delivery
# 51700  ['Pav with Veggie Bhaji', 'Six Grain Paratha',...        Delivery
# 51701                                                 []        Dine-out
# 51702  ['Veg Chinese Combo', 'Non Veg Chinese Combo',...        Delivery
# 51703  ['Chilli Potato', 'Chicken Kabab', 'Chicken Ro...        Delivery
# 51704                                                 []           Cafes
# 51705  ['Chicken Lollypop', 'Loaded Nachos', 'Peri Pe...        Delivery
# 51706                                                 []        Delivery
# 51707                                                 []        Delivery
# 51708                                                 []        Delivery
# 51709                                                 []        Dine-out
# 51710                                                 []        Delivery
# 51711  ['Maple Butter Waffle', 'Nutella Waffle', 'Cho...        Delivery
# 51712                                                 []        Delivery
# 51713                                                 []        Dine-out
# 51714                                                 []        Dine-out
# 51715                                                 []        Delivery
# 51716                                                 []        Desserts
#
#              listed_in(city)
# 0                  Jayanagar
# 1                        BTM
# 2             Residency Road
# 3                Frazer Town
# 4      Koramangala 6th Block
# 5              Church Street
# 6                Indiranagar
# 7            Electronic City
# 8               Brigade Road
# 9               Lavelle Road
# 10               Indiranagar
# 11                   MG Road
# 12                       HSR
# 13     Koramangala 7th Block
# 14         Bannerghatta Road
# 15          Old Airport Road
# 16     Koramangala 5th Block
# 17                  JP Nagar
# 18               Rajajinagar
# 19                       HSR
# 20               Rajajinagar
# 21     Koramangala 7th Block
# 22               Indiranagar
# 23                  JP Nagar
# 24                  JP Nagar
# 25              Brigade Road
# 26                       BTM
# 27     Koramangala 5th Block
# 28                 Jayanagar
# 29             Church Street
# ...                      ...
# 51687           Kammanahalli
# 51688                MG Road
# 51689  Koramangala 7th Block
# 51690            Brookefield
# 51691  Koramangala 5th Block
# 51692           Basavanagudi
# 51693         Residency Road
# 51694  Koramangala 5th Block
# 51695           Brigade Road
# 51696  Koramangala 7th Block
# 51697           Malleshwaram
# 51698               JP Nagar
# 51699      Bannerghatta Road
# 51700         Residency Road
# 51701          Church Street
# 51702         Residency Road
# 51703                    BTM
# 51704              Bellandur
# 51705               JP Nagar
# 51706  Koramangala 6th Block
# 51707              Bellandur
# 51708                    BTM
# 51709  Koramangala 7th Block
# 51710  Koramangala 5th Block
# 51711       Old Airport Road
# 51712      Bannerghatta Road
# 51713          Sarjapur Road
# 51714               JP Nagar
# 51715       Old Airport Road
# 51716  Koramangala 7th Block
#
# [51717 rows x 17 columns]

# %%
print(len(set(zomato['url'])))
print(len(set(zomato['name'])))
print(len(set(zomato['phone'])))
print(zomato['rate'].value_counts())
# Out:
# 51717
# 8792
# 14927
# NEW       2208
# 3.9/5     2098
# 3.8/5     2022
# 3.7/5     2011
# 3.9 /5    1874
# 3.8 /5    1851
# 3.7 /5    1810
# 3.6/5     1773
# 4.0/5     1609
# 4.0 /5    1574
# 3.6 /5    1543
# 4.1/5     1474
# 4.1 /5    1474
# 3.5/5     1431
# 3.5 /5    1353
# 3.4/5     1259
# 3.4 /5    1217
# 3.3/5     1168
# 4.2 /5    1165
# 3.3 /5    1142
# 4.2/5     1019
# 3.2/5     1006
# 4.3 /5     917
# 3.2 /5     867
# 3.1/5      862
# 4.3/5      776
# 3.1 /5     699
# 4.4 /5     628
# 3.0/5      558
# 4.4/5      519
#           ...
# 2.8/5      313
# 2.8 /5     287
# 4.5/5      247
# 4.6 /5     175
# 2.7/5      170
# 2.6/5      143
# 2.7 /5     137
# 4.6/5      125
# 2.6 /5     117
# 4.7 /5      86
# 4.7/5       81
# -           69
# 2.5 /5      56
# 2.5/5       45
# 4.8 /5      43
# 2.4/5       40
# 2.4 /5      30
# 4.9 /5      30
# 2.3/5       28
# 4.9/5       25
# 2.3 /5      23
# 4.8/5       23
# 2.2/5       19
# 2.1 /5      13
# 2.1/5       11
# 2.2 /5       7
# 2.0 /5       7
# 2.0/5        4
# 1.8 /5       3
# 1.8/5        2
# Name: rate, Length: 64, dtype: int64

# %% [markdown]
# ## A feleslegesnek vélt attribútumok eldobása

# %%
zomato = zomato.drop(['url',  'phone', 'location', 'rest_type', 'reviews_list', 'menu_item'], axis=1)

# %% [markdown]
# ## Az adatbázis tanító és teszt szettekre felbontása

# %%
import hashlib
import numpy as np

def split_train_test_by_id(data, test_ratio, id_column, hash=hashlib.md5):
 ids = data[id_column]
 in_test_set = ids.apply(lambda id_: test_set_check(id_, test_ratio, hash))
 return data.loc[~in_test_set], data.loc[in_test_set]

def test_set_check(identifier, test_ratio, hash):
 return hash(np.int64(identifier)).digest()[-1] < 256 * test_ratio

# %% [markdown]
# ## Szöveges oszlopok átalakítására való függvények

# %%
from sklearn.preprocessing import LabelEncoder

def yesNoConverter(column):
    encoder = LabelEncoder()
    column_converted = encoder.fit_transform(column)
    return column_converted

# %%
def label_factorize(df):
    for col in df.columns[~df.columns.isin(['rate', 'approx_cost(for two people)', 'votes', 'listed_in(type)', 'listed_in(city)'])]:
        df[col] = df[col].factorize()[0]
    return df

# %%
from sklearn.preprocessing import OneHotEncoder

def one_hotTransformer(zomato_encoded):
    encoder = OneHotEncoder(categories='auto')
    zomato_cat_1hot = encoder.fit_transform(zomato_encoded.reshape(-1,1))
    return zomato_cat_1hot

# %%
type_labels = list()
city_labels = list()

def labelEncoder(column, city):
    global type_labels
    global city_labels
    encoder = LabelEncoder()
    zomato_cat_encoded = encoder.fit_transform(column)
    if city:
        city_labels = list(encoder.classes_)
    else:
        type_labels = list(encoder.classes_)
    
    return zomato_cat_encoded

# %% [markdown]
# ## A 'rate' oszlop megtisztítására való függvény

# %% [markdown]
# Eredetileg '4.1 / 5', 'NEW', '-', '3.5/5' formákban találhatóak az adatok.
# Ezekből csak az első tag kellene, a szöveges információkat pedig nan értékekkel helyettesítjük.

# %%
import string

 
def isfloat(value):
  try:
    float(value)
    return True
  except ValueError:
    return False

def cleanRates(data):
    if(isinstance(data, float)):
        return data
    else:
        cleanData = data.translate({ord(c): None for c in string.whitespace})
        vote = cleanData.split('/')
        if (isfloat(vote[0])):
            return float(vote[0])
        else:
            return np.nan

# %% [markdown]
# ## Medián kiszámítására használatos függvény

# %% [markdown]
# Minden olyan adatot, amit később fel kell használni a teszt szettel való műveletek során, egy-egy globális dictionary-be mentjük el.
# Az egyes oszlopokhoz tartozó értékek az oszlop neve alapján érthetőek el (ez a kulcs).

# %%
def calculateMedianByColumnName(column, column_name):
    items_cleaned = []
    numpy_array = np.array(column)
    for x in numpy_array:
        if not np.isnan(x):
            items_cleaned.append(x)
            
    global median      
    median[column_name] = np.median(items_cleaned)
    return median[column_name]

# %%
# csak inicializálás, hogy meglegyenek globálisan
median = dict()

def replaceNanByMedian(column, column_name, training):
    if training:
        global median
        median[column_name] = calculateMedianByColumnName(column, column_name)
        
    column_cleaned = []
    numpy_array = np.array(column)
    for x in numpy_array:
        if np.isnan(x):
            column_cleaned.append(median[column_name])
        else:
            column_cleaned.append(x)
    return column_cleaned

# %% [markdown]
# ## Standard és MinMax skálázó

# %%
# csak inicializálás, hogy meglegyenek globálisan
mean = dict()
variance = dict()

def standardScaler(column, column_name, training):
    if training:
        global mean
        mean[column_name] = np.mean(column)
        global variance
        variance[column_name] = np.var(column)
        
    standardizedCol = []
    for x in column:
        standardizedCol.append((x - mean[column_name]) / variance[column_name])
   
    return standardizedCol

# %%
# csak inicializálás, hogy meglegyenek globálisan
min_value = dict()
max_value = dict()

def Normalize(column, column_name, training):
    if training:
        global min_value
        min_value[column_name] = float(column.min())
        global max_value
        max_value[column_name] = float(column.max())
        
    column_substract = []
    for x in column:
        column_substract.append((float(x)-min_value[column_name])/(max_value[column_name]-min_value[column_name]))
    return column_substract

# %% [markdown]
# ### Apróbb függvény, ami a tizedesvesszőt tartalmazó számadatokból kiveszi a tizedesvesszőt. (Tizedesvesszővel string formátumban vannak)

# %%
def ConvertFromMoneyToString(column):
    column_converted = []
    for x in column:
        if not isfloat(x):
            x = x.replace(",", "")
            column_converted.append(float(x))
        else:
            column_converted.append(float(x))
    return column_converted

# %% [markdown]
# ## Az eredmények megjelenítéséért felelős függvények

# %%
def display_scores(scores):
    print("Scores:", scores)
    print("Mean:", scores.mean())
    print("Standard deviation:", scores.std())
    print("\n")

# %%
def displayLinRegPredictions(lin_reg, train_set_ready_df, labels_ready):
    some_data = train_set_ready_df.iloc[:5]
    #some_data = train_set.iloc[:5]
    some_labels = pd.DataFrame(data=labels_ready).iloc[:5]

    print("Predictions:\t", lin_reg.predict(train_set_ready_df.iloc[:5]))
    print("Labels:\t\t", some_labels)
    print("\n")

# %%
statistic_table = pd.DataFrame()

def printToStatistics(name, rmse, details, pg, mean='Nan', sd='NaN'):
    global statistic_table 
    statistic_table = statistic_table.append({'name' : name , 
                                              'rmse' : rmse , 
                                              'details' : details,
                                              'mean' : mean,
                                              'standard deviation' : sd,
                                              'purging' : pg
                                             } , ignore_index=True)

# %% [markdown]
# ## Saját pipeline egy függvény formájában

# %% [markdown]
# A szükséges helyeken a hiányzó értékeket -1-ekkel töltjük fel, mert ez adta a legjobb eredményt.
# A paraméterben megadható skálázóval skálázzuk a megfelelő attribútumokat az adat "megtisztítása" után (pl. string --> float).
# Némely paraméterre OneHot kódolót is használunk, mert így sikerült a legjobb eredményt elérni.
# Miután minden paramétert feldolgoztunk, egy mátrixot rakunk össze a paraméterekből.

# %%
# csak hogy globális legyen
zomato_labels =  []

def runPipeline(dataset, training, scaler):
    dataset_ready = dataset.copy()
    
    dataset_ready = label_factorize(dataset_ready)
    #dataset_ready = dataset_ready.drop(['rate'], axis=1).fillna(-1) #filling nan values by -1
    dataset_ready['name'] = dataset_ready['name'].fillna(-1)
    dataset_ready['cuisines'] = dataset_ready['cuisines'].fillna(-1)
    dataset_ready['dish_liked'] = dataset_ready['dish_liked'].fillna(-1)
    dataset_ready['address'] = dataset_ready['address'].fillna(-1)
    
    dataset_ready['online_order'] = yesNoConverter(dataset_ready['online_order'])
    dataset_ready['book_table'] = yesNoConverter(dataset_ready['book_table'])
    
    dataset_type_encoded = labelEncoder(dataset_ready['listed_in(type)'], False)
    dataset_type_encoded_oneHot = one_hotTransformer(dataset_type_encoded)
        
    dataset_city_encoded = labelEncoder(dataset_ready['listed_in(city)'], True)
    dataset_city_encoded_oneHot = one_hotTransformer(dataset_city_encoded)
    
    dataset_ready['approx_cost(for two people)'] = ConvertFromMoneyToString(dataset_ready['approx_cost(for two people)'])
    dataset_ready['approx_cost(for two people)'] = replaceNanByMedian(dataset_ready['approx_cost(for two people)'], "approx_cost(for two people)", training)
    dataset_ready['approx_cost(for two people)'] = scaler(dataset_ready['approx_cost(for two people)'], "approx_cost(for two people)", training)
    dataset_ready['name'] = scaler(dataset_ready['name'], "name", training)
    dataset_ready['address'] = scaler(dataset_ready['address'], "address", training)
    dataset_ready['dish_liked'] = scaler(dataset_ready['dish_liked'], "dish_liked", training)
    dataset_ready['cuisines'] = scaler(dataset_ready['cuisines'], "cuisines", training)
    dataset_ready['votes'] = scaler(dataset_ready['votes'], "votes", training)
    dataset_num = dataset_ready.drop(['listed_in(type)', 'listed_in(city)', 'rate'], axis=1)
    dataset_ready = np.concatenate((np.concatenate((dataset_num, dataset_type_encoded_oneHot.toarray()), axis=1), dataset_city_encoded_oneHot.toarray()), axis=1)
    return dataset_ready

# %% [markdown]
# ## Az adat betanítása, majd a betanított adatbázison futtatása a modelleknek

# %% [markdown]
# Nem ad vissza adatot, futás közben az összes modellel produkált eredményt sorban kiírja.

# %%
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import cross_val_score
from sklearn.metrics import mean_squared_error
from sklearn.linear_model import LinearRegression

def trainDataWithGivenScalerAndRunAllModels(dataset, labels, scaler, details, purging):
    dataset_ready = runPipeline(dataset, True, scaler)
    dataset_ready_df = pd.DataFrame(dataset_ready)
    
    # Lineáris regresszió    
    lin_reg = LinearRegression()
    lin_reg.fit(dataset_ready, labels)
    train_set_predictions = lin_reg.predict(dataset_ready_df)
    lin_mse = mean_squared_error(labels, train_set_predictions)
    lin_rmse = np.sqrt(lin_mse)
    printToStatistics('LinearRegression', lin_rmse, details, purging, lin_rmse)
    print("Linear Regression with", details)
    displayLinRegPredictions(lin_reg, dataset_ready_df, labels)
    
    # Döntési fa
    tree_reg = DecisionTreeRegressor()
    tree_reg.fit(dataset_ready, labels)
    train_set_predictions = tree_reg.predict(dataset_ready_df)
    tree_mse = mean_squared_error(labels, train_set_predictions)
    tree_rmse = np.sqrt(tree_mse)
    decision_tree_scores = cross_val_score(tree_reg, dataset_ready_df, labels, scoring="neg_mean_squared_error", cv=10)
    tree_rmse_scores = np.sqrt(-decision_tree_scores)
    printToStatistics('DecisionTreeRegressor', tree_rmse, details, purging, tree_rmse_scores.mean(), tree_rmse_scores.std())
    print("Decision Tree with", details)
    display_scores(tree_rmse_scores)
    
    # Random forest
    forest_reg = RandomForestRegressor(10)
    forest_reg.fit(dataset_ready_df, pd.DataFrame(data=labels).values.ravel())
    train_set_predictions = forest_reg.predict(dataset_ready_df)
    forest_mse = mean_squared_error(labels, train_set_predictions)
    forest_rmse = np.sqrt(forest_mse)
    forest_scores = cross_val_score(forest_reg, dataset_ready_df, pd.DataFrame(data=labels).values.ravel(), scoring="neg_mean_squared_error", cv=10)
    forest_rmse_scores = np.sqrt(-forest_scores)
    printToStatistics('RandomForestRegressor', forest_rmse, details, purging, forest_rmse_scores.mean(), forest_rmse_scores.std())
    print("Random forest with", details)
    display_scores(forest_rmse_scores)

# %% [markdown]
# ## Az adatbázis kezdeti feldolgozása

# %% [markdown]
# Cél attribútum üres értéket tartalmazó sorokat eldobjuk (ehhez előbb szükséges az értékelések átalakítása nekünk megfelelő (4.1/5 --> 4.1) formába).
# Majd tanító és teszt szettekre bontása.

# %%
import seaborn as sns

#MAIN
dataset = zomato.copy()
cleaned_rate_labels = []
        
dataset = dataset.loc[dataset['rate'] !='NEW']
dataset = dataset.loc[dataset['rate'] !='-'].reset_index(drop=True)

for n in dataset['rate']:
    cleaned_rate_labels.append(float(cleanRates(n)))
dataset['rate'] = cleaned_rate_labels
dataset = dataset.drop(dataset[np.isnan(dataset['rate'])].index)

dataset = dataset.reset_index()

train_set, test_set = split_train_test_by_id(dataset, 0.2, "index")

train_labels = train_set['rate']
train_set = train_set.drop('index', axis=1)
test_labels = test_set['rate']
test_set = test_set.drop('index', axis=1)

# %% [markdown]
# ## A modellek kipróbálása mindkét skálázóval

# %%
print("Running Models with MinMax")
trainDataWithGivenScalerAndRunAllModels(train_set, train_labels, Normalize, "MinMaxNorm with Basic Data", "No")

print("Running Models with StandardScaler")
trainDataWithGivenScalerAndRunAllModels(train_set, train_labels, standardScaler, "StandardScaler with Basic Data", "No")
# Out:
# Running Models with MinMax
# Linear Regression with MinMaxNorm with Basic Data
# Predictions:	 [3.63699341 3.63171387 3.60440063 4.02145386 3.47747803]
# Labels:		    rate
# 0   3.7
# 1   3.9
# 2   4.0
# 3   4.0
# 6   3.2
#
#
# Decision Tree with MinMaxNorm with Basic Data
# Scores: [0.18569618 0.1985589  0.19977315 0.2057754  0.18159992 0.1969836
#  0.19116405 0.18797377 0.19405279 0.20503195]
# Mean: 0.1946609712602571
# Standard deviation: 0.00765562511463098
#
#
# Random forest with MinMaxNorm with Basic Data
# Scores: [0.16244532 0.1604302  0.17188223 0.16293934 0.15719302 0.16178977
#  0.15886066 0.16606912 0.16078147 0.16132165]
# Mean: 0.16237127836368584
# Standard deviation: 0.003890171571061184
#
#
# Running Models with StandardScaler
# Linear Regression with StandardScaler with Basic Data
# Predictions:	 [3.64257812 3.63085938 3.6015625  4.02539062 3.48046875]
# Labels:		    rate
# 0   3.7
# 1   3.9
# 2   4.0
# 3   4.0
# 6   3.2
#
#
# Decision Tree with StandardScaler with Basic Data
# Scores: [0.19099276 0.19759742 0.20290365 0.20292688 0.18167483 0.19447307
#  0.19654561 0.1941229  0.19433308 0.20488441]
# Mean: 0.19604546235391868
# Standard deviation: 0.006452286526622044
#
#
# Random forest with StandardScaler with Basic Data
# Scores: [0.16042247 0.15813443 0.16840124 0.16125162 0.15693552 0.16388041
#  0.16060194 0.16363722 0.16037386 0.16238406]
# Mean: 0.16160227833565402
# Standard deviation: 0.0030658947004375296

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
ax = statistic_table.plot.hist(bins=12, alpha=0.5)

# %% [markdown]
# ## A 'votes' oszlopból a kiugró értékek helyettesítése az általunk megadott maximum értékkel, majd a modellek ismételt futtatása a 'purgált' adatbázissal

# %%
#PURGÁLÁS
zomato_with_id = zomato.reset_index()
purged_dataset = dataset.copy()
#purged_dataset = dataset.drop(dataset[dataset["votes"] > 5000].index)
purged_dataset["votes"].where(purged_dataset["votes"] < 5000, 5000, inplace=True)
print(purged_dataset.shape)
purged_dataset = purged_dataset.reset_index()

second_train_set, second_test_set = split_train_test_by_id(purged_dataset, 0.2, "index")
second_train_labels = second_train_set['rate']
second_train_set = second_train_set.drop('index', axis=1)
second_test_labels = second_test_set['rate']
second_test_set = second_test_set.drop('index', axis=1)

print("Running Models with MinMax")
trainDataWithGivenScalerAndRunAllModels(second_train_set, second_train_labels,  Normalize, "MinMaxNorm with Purged Data", "Yes")

print("Running Models with StandardScaler")
trainDataWithGivenScalerAndRunAllModels(second_train_set, second_train_labels, standardScaler, "StandardScaler  with Purged Data", "Yes")
# Out:
# (41665, 12)
# Running Models with MinMax
# Linear Regression with MinMaxNorm with Purged Data
# Predictions:	 [3.64167604 3.62565604 3.60713921 4.0353307  3.477026  ]
# Labels:		    rate
# 0   3.7
# 1   3.9
# 2   4.0
# 3   4.0
# 6   3.2
#
#
# Decision Tree with MinMaxNorm with Purged Data
# Scores: [0.21249511 0.22548483 0.21145406 0.21566979 0.19034767 0.19854323
#  0.19496226 0.197367   0.19269232 0.25977707]
# Mean: 0.20987933251143853
# Standard deviation: 0.019901334414170406
#
#
# Random forest with MinMaxNorm with Purged Data
# Scores: [0.19204092 0.1782065  0.17790617 0.16944947 0.16234243 0.16125444
#  0.16854354 0.17344052 0.17041448 0.1743896 ]
# Mean: 0.17279880747924276
# Standard deviation: 0.008403263339522375
#
#
# Running Models with StandardScaler
# Linear Regression with StandardScaler  with Purged Data
# Predictions:	 [3.64167605 3.62565603 3.60713918 4.03533072 3.47702602]
# Labels:		    rate
# 0   3.7
# 1   3.9
# 2   4.0
# 3   4.0
# 6   3.2
#
#
# Decision Tree with StandardScaler  with Purged Data
# Scores: [0.21720857 0.23077206 0.21181829 0.21966382 0.18473659 0.1937799
#  0.19752016 0.19593696 0.19128265 0.26436933]
# Mean: 0.21070883281313338
# Standard deviation: 0.02266345686725853
#
#
# Random forest with StandardScaler  with Purged Data
# Scores: [0.18898203 0.18251675 0.18145905 0.16712225 0.1622571  0.17117534
#  0.16671809 0.17152617 0.16818856 0.18166893]
# Mean: 0.1741614262307128
# Standard deviation: 0.008350344093710228

# %% [markdown]
# ## Feldolgozott (fit hívás) adatbázisok elmentése későbbi használatra

# %%
train_set_ready_with_minmax = runPipeline(train_set, True, Normalize)

train_set_ready_with_standard_scaler = runPipeline(train_set, True, standardScaler)

# %%
print(train_set_ready_with_minmax.shape)
print(train_set_ready_with_minmax)
# Out:
# (33073, 45)
# [[0.00000000e+00 0.00000000e+00 0.00000000e+00 ... 0.00000000e+00
#   0.00000000e+00 0.00000000e+00]
#  [1.17647059e-04 1.54918668e-04 0.00000000e+00 ... 0.00000000e+00
#   0.00000000e+00 0.00000000e+00]
#  [2.35294118e-04 3.09837335e-04 0.00000000e+00 ... 1.00000000e+00
#   0.00000000e+00 0.00000000e+00]
#  ...
#  [6.05058824e-01 1.44384198e-01 0.00000000e+00 ... 0.00000000e+00
#   0.00000000e+00 0.00000000e+00]
#  [7.62588235e-01 9.06274206e-02 1.00000000e+00 ... 0.00000000e+00
#   0.00000000e+00 0.00000000e+00]
#  [7.33764706e-01 1.18202943e-01 0.00000000e+00 ... 0.00000000e+00
#   0.00000000e+00 0.00000000e+00]]

# %%
statistic_table
# Out:
#                              details      mean                   name purging  \
# 0         MinMaxNorm with Basic Data  0.346925       LinearRegression      No
# 1         MinMaxNorm with Basic Data  0.194661  DecisionTreeRegressor      No
# 2         MinMaxNorm with Basic Data  0.162371  RandomForestRegressor      No
# 3     StandardScaler with Basic Data  0.346951       LinearRegression      No
# 4     StandardScaler with Basic Data  0.196045  DecisionTreeRegressor      No
# 5     StandardScaler with Basic Data  0.161602  RandomForestRegressor      No
# 6        MinMaxNorm with Purged Data  0.343548       LinearRegression     Yes
# 7        MinMaxNorm with Purged Data  0.209879  DecisionTreeRegressor     Yes
# 8        MinMaxNorm with Purged Data  0.172799  RandomForestRegressor     Yes
# 9   StandardScaler  with Purged Data  0.343548       LinearRegression     Yes
# 10  StandardScaler  with Purged Data  0.210709  DecisionTreeRegressor     Yes
# 11  StandardScaler  with Purged Data  0.174161  RandomForestRegressor     Yes
#
#             rmse standard deviation
# 0   3.469253e-01                NaN
# 1   6.206206e-16         0.00765563
# 2   6.724757e-02         0.00389017
# 3   3.469507e-01                NaN
# 4   6.206734e-16         0.00645229
# 5   6.746340e-02         0.00306589
# 6   3.435484e-01                NaN
# 7   6.215375e-16          0.0199013
# 8   7.070615e-02         0.00840326
# 9   3.435484e-01                NaN
# 10  6.212784e-16          0.0226635
# 11  7.124273e-02         0.00835034

# %% [markdown]
# ## Cross Validation futtatása a legjobb modellel

# %%
from sklearn.model_selection import GridSearchCV
param_grid = [
     {'bootstrap': [False], 'n_estimators': [10, 15, 20], 'max_features': [3, 5, 10]},
 ]
forest_reg = RandomForestRegressor()
grid_search = GridSearchCV(forest_reg, param_grid, cv=10, scoring='neg_mean_squared_error')
grid_search.fit(train_set_ready_with_standard_scaler, train_labels)
# Out:
# GridSearchCV(cv=10, error_score='raise-deprecating',
#        estimator=RandomForestRegressor(bootstrap=True, criterion='mse', max_depth=None,
#            max_features='auto', max_leaf_nodes=None,
#            min_impurity_decrease=0.0, min_impurity_split=None,
#            min_samples_leaf=1, min_samples_split=2,
#            min_weight_fraction_leaf=0.0, n_estimators='warn', n_jobs=None,
#            oob_score=False, random_state=None, verbose=0, warm_start=False),
#        fit_params=None, iid='warn', n_jobs=None,
#        param_grid=[{'bootstrap': [False], 'n_estimators': [10, 15, 20], 'max_features': [3, 5, 10]}],
#        pre_dispatch='2*n_jobs', refit=True, return_train_score='warn',
#        scoring='neg_mean_squared_error', verbose=0)

# %%
print(grid_search.best_params_)
print(grid_search.best_estimator_)
# Out:
# {'bootstrap': False, 'max_features': 10, 'n_estimators': 20}
# RandomForestRegressor(bootstrap=False, criterion='mse', max_depth=None,
#            max_features=10, max_leaf_nodes=None, min_impurity_decrease=0.0,
#            min_impurity_split=None, min_samples_leaf=1,
#            min_samples_split=2, min_weight_fraction_leaf=0.0,
#            n_estimators=20, n_jobs=None, oob_score=False,
#            random_state=None, verbose=0, warm_start=False)

# %%
cvres = grid_search.cv_results_
for mean_score, params in zip(cvres["mean_test_score"], cvres["params"]):
    print(np.sqrt(-mean_score), params)
print('min: ', np.sqrt(-cvres["mean_test_score"].max()))
# Out:
# 0.2639017033284943 {'bootstrap': False, 'max_features': 3, 'n_estimators': 10}
# 0.2633101026753478 {'bootstrap': False, 'max_features': 3, 'n_estimators': 15}
# 0.2589282021584531 {'bootstrap': False, 'max_features': 3, 'n_estimators': 20}
# 0.21603343434960384 {'bootstrap': False, 'max_features': 5, 'n_estimators': 10}
# 0.21132367786299008 {'bootstrap': False, 'max_features': 5, 'n_estimators': 15}
# 0.20578716418483656 {'bootstrap': False, 'max_features': 5, 'n_estimators': 20}
# 0.1613025717041601 {'bootstrap': False, 'max_features': 10, 'n_estimators': 10}
# 0.15538945268301418 {'bootstrap': False, 'max_features': 10, 'n_estimators': 15}
# 0.15174090972534132 {'bootstrap': False, 'max_features': 10, 'n_estimators': 20}
# min:  0.15174090972534132

# %%
#from sklearn.model_selection import RandomizedSearchCV
#forest_reg = RandomForestRegressor()
#from scipy.stats import randint as sp_randint
#param_dist = {
 #             "max_features": sp_randint(2, 45),
  #            "bootstrap": [True, False],
  #            'n_estimators': sp_randint(3, 10)}
#n_iter_search = 10
#rand_search = RandomizedSearchCV(forest_reg,param_distributions=param_dist, n_iter=n_iter_search, cv=10, scoring='neg_mean_squared_error')
#rand_search.fit(train_set_ready_with_minmax, train_labels)

# %% [markdown]
# ## Csak a vizualizáció kedvéért újra lefuttatás

# %%
best_predictions = grid_search.best_estimator_.predict(train_set_ready_with_standard_scaler)
abs_error_array = abs(best_predictions - train_labels)

# %%
plt.figure(figsize=(6,6))
sns.distplot(abs_error_array)
plt.show()

# %%
best_estimator_scores_ = cross_val_score(grid_search.best_estimator_, train_set_ready_with_standard_scaler, train_labels, scoring="neg_mean_squared_error", cv=10)
best_estimator_scores = np.sqrt(-best_estimator_scores_)

# %%
plt.figure(figsize=(6,6))
sns.distplot(best_estimator_scores)
plt.show()

# %%
feature_importances = grid_search.best_estimator_.feature_importances_
feature_importances
# Out:
# array([0.09062108, 0.09377265, 0.0127162 , 0.07104126, 0.25841879,
#        0.19799146, 0.09718329, 0.09159105, 0.00169563, 0.00276815,
#        0.00329211, 0.00699864, 0.00330857, 0.00151454, 0.00059678,
#        0.00182896, 0.00145045, 0.00297984, 0.00174732, 0.00351192,
#        0.00099329, 0.00427455, 0.00090626, 0.00362398, 0.00123654,
#        0.00281068, 0.00345373, 0.00233268, 0.00164418, 0.00206767,
#        0.00211589, 0.00107503, 0.00092132, 0.00088912, 0.00107658,
#        0.00096536, 0.00103895, 0.00261778, 0.00492012, 0.00238213,
#        0.00336387, 0.00244887, 0.00106762, 0.00308727, 0.00365781])

# %%
def plot_importances(model, cols):
    plt.figure(figsize=(12,6))
    f_imp = pd.Series(model.feature_importances_, index=cols).sort_values(ascending=True)
    f_imp.plot(kind='barh')

# %% [markdown]
# ## Az egyes attribútumok 'fontossága' a predikcióban

# %%
attributes = ['address', 'name', 'online_order', 'book_table', 'votes', 'dish_liked', 'cuisines', 'approx_cost(for two people)'] + type_labels + city_labels
sorted(zip(feature_importances, attributes), reverse=True)
# Out:
# [(0.2584187915582178, 'votes'),
#  (0.19799145589059153, 'dish_liked'),
#  (0.09718328976868823, 'cuisines'),
#  (0.0937726546059931, 'name'),
#  (0.09159104857949366, 'approx_cost(for two people)'),
#  (0.09062108320090236, 'address'),
#  (0.07104125689480266, 'book_table'),
#  (0.012716203079226645, 'online_order'),
#  (0.006998638890763737, 'Desserts'),
#  (0.004920120099728685, 'Marathahalli'),
#  (0.004274552548436875, 'Brookefield'),
#  (0.003657814354818896, 'Whitefield'),
#  (0.003623982354316063, 'Electronic City'),
#  (0.003511919312900785, 'Bellandur'),
#  (0.0034537257870401634, 'Indiranagar'),
#  (0.0033638678452444734, 'Old Airport Road'),
#  (0.0033085702252581063, 'Dine-out'),
#  (0.0032921094951283572, 'Delivery'),
#  (0.0030872705884020593, 'Sarjapur Road'),
#  (0.0029798392215942835, 'Bannerghatta Road'),
#  (0.002810678431461654, 'HSR'),
#  (0.00276815098873871, 'Cafes'),
#  (0.0026177807990655517, 'Malleshwaram'),
#  (0.002448873753276911, 'Rajajinagar'),
#  (0.0023821341656855275, 'New BEL Road'),
#  (0.0023326788236674076, 'JP Nagar'),
#  (0.002115890752450205, 'Kammanahalli'),
#  (0.0020676708932998067, 'Kalyan Nagar'),
#  (0.001828955689077421, 'BTM'),
#  (0.0017473189999941193, 'Basavanagudi'),
#  (0.0016956301608696983, 'Buffet'),
#  (0.0016441841138923308, 'Jayanagar'),
#  (0.0015145392730953118, 'Drinks & nightlife'),
#  (0.0014504473446960244, 'Banashankari'),
#  (0.0012365419803717637, 'Frazer Town'),
#  (0.0010765841532783412, 'Koramangala 7th Block'),
#  (0.0010750330850360483, 'Koramangala 4th Block'),
#  (0.001067617629825469, 'Residency Road'),
#  (0.0010389501865312495, 'MG Road'),
#  (0.00099329268285441, 'Brigade Road'),
#  (0.0009653621999720117, 'Lavelle Road'),
#  (0.0009213233786046056, 'Koramangala 5th Block'),
#  (0.000906263437256584, 'Church Street'),
#  (0.0008891195706721549, 'Koramangala 6th Block'),
#  (0.0005967832047782051, 'Pubs and bars')]

# %%
plot_importances(grid_search.best_estimator_, attributes)

# %% [markdown]
# ## Végül a teszt szetten futtatás, mérés

# %%
final_model = grid_search.best_estimator_

X_test = runPipeline(test_set, False, standardScaler)
y_test = test_labels

# %%
print(len(y_test))
X_test_df = pd.DataFrame(X_test)
final_predictions = final_model.predict(X_test_df)
final_mse = mean_squared_error(y_test, final_predictions)
final_rmse = np.sqrt(final_mse)
display_scores(final_rmse)
# Out:
# 8592
# Scores: 0.31779177820133264
# Mean: 0.31779177820133264
# Standard deviation: 0.0

# %%
y_test.plot(kind='hist', label='true values')
pd.Series(final_predictions).plot(kind='hist', label='predictions')
plt.legend()

# %% [markdown]
# ## Model vizsgálata, mi alapján dönt a döntési fa

# %%
from sklearn.tree import export_graphviz
from IPython.display import Image
import pydot
def convert_dot_to_png(model, max_depth=5, feature_names=list(attributes)):
    export_graphviz(model.estimators_[0], out_file='tree.dot', max_depth=max_depth, feature_names=feature_names, rounded=True)
    (graph,) = pydot.graph_from_dot_file('tree.dot')
    graph.write_png('tree.png')

# %%
convert_dot_to_png(final_model)
Image('tree.png')

# %% [markdown]
# ## Lokáció (GPS koordináták) hozzáadása

# %%
def generateBaseMap(default_location=[12.97, 77.59], default_zoom_start=12):
    base_map = folium.Map(location=default_location, control_scale=True, zoom_start=default_zoom_start)
    return base_map

# %% [markdown]
# Geopy segítségével a lokációk koordiánátinak lekérése.

# %%
def get_lat_lon(df):
    locations=pd.DataFrame({"Name":zomato['location'].unique()})
    locations['Name']=locations['Name'].apply(lambda x: "Bangalore " + str(x))
    lat=[]
    lon=[]
    geolocator=Nominatim(user_agent="app")
    for location in locations['Name']:
        location = geolocator.geocode(location)
        if location is None:
            lat.append(np.nan)
            lon.append(np.nan)
        else:    
            lat.append(location.latitude)
            lon.append(location.longitude)
    locations['lat']=lat
    locations['lon']=lon
    return locations

# %%
from geopy.geocoders import Nominatim

zomato_loc = backup_zomato.copy()
locations=pd.DataFrame({"Name":zomato_loc['location'].unique()})
locations['Name']=locations['Name'].apply(lambda x: "Bangalore " + str(x))
lat_lon=[]
geolocator=Nominatim(user_agent="app")
for location in locations['Name']:
    location = geolocator.geocode(location)
    if location is None:
        lat_lon.append(np.nan)
    else:    
        geo=(location.latitude,location.longitude)
        lat_lon.append(geo)

locations['geo_loc']=lat_lon

# %%
locations["Name"]=locations['Name'].apply(lambda x :  x.replace("Bangalore","")[1:])
locations.head()
# Out:
#                     Name                          geo_loc
# 0                    BTM  (12.91127585, 77.6045654343118)
# 1         St. Marks Road         (12.9779057, 77.6022008)
# 2          Church Street         (12.9742939, 77.6525189)
# 3  Koramangala 6th Block         (13.2923988, 77.7519261)
# 4           Shanti Nagar         (12.9575547, 77.5979099)

# %%
Rest_locations=pd.DataFrame(zomato_loc['location'].value_counts().reset_index())
Rest_locations.columns=['Name','count']
Rest_locations=Rest_locations.merge(locations,on='Name',how="left").dropna()
Rest_locations['count'].max()
# Out:
# 5124

# %%
from folium.plugins import HeatMap
import folium

lat,lon=zip(*np.array(Rest_locations['geo_loc']))
Rest_locations['lat']=lat
Rest_locations['lon']=lon
basemap=generateBaseMap()
HeatMap(Rest_locations[['lat','lon','count']].values.tolist(),zoom=20,radius=15).add_to(basemap)

# %%
basemap
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# A helyek összepárosítása a gps koordinátákkal.

# %%
loc_dict = dict(zip(zomato_loc['location'].unique(), locations['geo_loc']))
loc_array = list()
for x in zomato_loc['location']:
    loc_array.append(loc_dict[x])

# %% [markdown]
# NaN értékek lecserélése (-1, -1)-ekre a gps koordinátáknál.

# %%
nan_free_loc_array = []
for x in loc_array:
    if(x != x):
        nan_free_loc_array.append((-1, -1))
    else:
        nan_free_loc_array.append(x)

# %% [markdown]
# ## Új dataset létrehozása, azon szokásos feldolgozás elvégzése

# %%
extended_dataset = zomato.copy()
cleaned_rate_labels = []

list_of_lat = [x[0] for x in nan_free_loc_array]
list_of_lon = [x[1] for x in nan_free_loc_array]

extended_dataset['lat'] = list_of_lat
extended_dataset['lon'] = list_of_lon

extended_dataset = extended_dataset.loc[extended_dataset['rate'] !='NEW']
extended_dataset = extended_dataset.loc[extended_dataset['rate'] !='-'].reset_index(drop=True)

for n in extended_dataset['rate']:
    cleaned_rate_labels.append(float(cleanRates(n)))
extended_dataset['rate'] = cleaned_rate_labels
extended_dataset = extended_dataset.drop(extended_dataset[np.isnan(extended_dataset['rate'])].index)

extended_dataset = extended_dataset.reset_index()

extended_train_set, extended_test_set = split_train_test_by_id(extended_dataset, 0.2, "index")

extended_train_labels = extended_train_set['rate']
extended_train_set = extended_train_set.drop('index', axis=1)
extended_test_labels = extended_test_set['rate']
extended_test_set = extended_test_set.drop('index', axis=1)

# %% [markdown]
# Az új attribútumok skálázása külön, hiszen ez előtt meghívva nem léteznek még, így a függvényben nem kivitelezhető.
#
# Skálázatlan oszlopok kimentése a későbbi vizualizációra való felhasználásra.

# %%
not_scaled_extended_train_set = pd.DataFrame()
not_scaled_extended_train_set['lat'] = extended_train_set['lat']
not_scaled_extended_train_set['lon'] = extended_train_set['lon']

extended_train_set['lat'] = standardScaler(extended_train_set['lat'], "lat", True)
extended_train_set['lon'] = standardScaler(extended_train_set['lon'], "lon", True)

extended_test_set['lat'] = standardScaler(extended_test_set['lat'], "lat", False)
extended_test_set['lon'] = standardScaler(extended_test_set['lon'], "lon", False)

# %% [markdown]
# A maradék adat végigfuttatása a Pipeline-on, feldolgozott dataset elmentése (extended_train_set_ready_with_standard_scaler).

# %%
trainDataWithGivenScalerAndRunAllModels(extended_train_set, extended_train_labels,  standardScaler, "StandardScaler with Lat Lon Data", "No")
# Out:
# Linear Regression with StandardScaler with Lat Lon Data
# Predictions:	 [3.63051179 3.62736629 3.59471719 4.01243114 3.47330443]
# Labels:		    rate
# 0   3.7
# 1   3.9
# 2   4.0
# 3   4.0
# 6   3.2
#
#
# Decision Tree with StandardScaler with Lat Lon Data
# Scores: [0.18186359 0.18545998 0.19790316 0.16922242 0.18184952 0.18860011
#  0.17267178 0.18237256 0.17804332 0.19320949]
# Mean: 0.18311959296609348
# Standard deviation: 0.008292640073783409
#
#
# Random forest with StandardScaler with Lat Lon Data
# Scores: [0.15472769 0.15310846 0.16232441 0.15591406 0.1501063  0.15431756
#  0.15080983 0.16126803 0.1490144  0.15591386]
# Mean: 0.15475046069813045
# Standard deviation: 0.004188485962853952

# %%
extended_train_set_ready_with_standard_scaler = runPipeline(extended_train_set, True, standardScaler)

# %% [markdown]
# ## GridSearch Cross Validation lefuttatása

# %%
grid_search.fit(extended_train_set_ready_with_standard_scaler, extended_train_labels)
# Out:
# GridSearchCV(cv=10, error_score='raise-deprecating',
#        estimator=RandomForestRegressor(bootstrap=True, criterion='mse', max_depth=None,
#            max_features='auto', max_leaf_nodes=None,
#            min_impurity_decrease=0.0, min_impurity_split=None,
#            min_samples_leaf=1, min_samples_split=2,
#            min_weight_fraction_leaf=0.0, n_estimators='warn', n_jobs=None,
#            oob_score=False, random_state=None, verbose=0, warm_start=False),
#        fit_params=None, iid='warn', n_jobs=None,
#        param_grid=[{'bootstrap': [False], 'n_estimators': [10, 15, 20], 'max_features': [3, 5, 10]}],
#        pre_dispatch='2*n_jobs', refit=True, return_train_score='warn',
#        scoring='neg_mean_squared_error', verbose=0)

# %%
cvres = grid_search.cv_results_
for mean_score, params in zip(cvres["mean_test_score"], cvres["params"]):
    print(np.sqrt(-mean_score), params)
print('min: ', np.sqrt(-cvres["mean_test_score"].max()))
# Out:
# 0.24362062039611482 {'bootstrap': False, 'max_features': 3, 'n_estimators': 10}
# 0.23813464968630227 {'bootstrap': False, 'max_features': 3, 'n_estimators': 15}
# 0.23282284654225086 {'bootstrap': False, 'max_features': 3, 'n_estimators': 20}
# 0.19336376952500697 {'bootstrap': False, 'max_features': 5, 'n_estimators': 10}
# 0.1902077945731422 {'bootstrap': False, 'max_features': 5, 'n_estimators': 15}
# 0.18391633342430155 {'bootstrap': False, 'max_features': 5, 'n_estimators': 20}
# 0.1475862189184149 {'bootstrap': False, 'max_features': 10, 'n_estimators': 10}
# 0.13978424043463697 {'bootstrap': False, 'max_features': 10, 'n_estimators': 15}
# 0.13681191374711135 {'bootstrap': False, 'max_features': 10, 'n_estimators': 20}
# min:  0.13681191374711135

# %% [markdown]
# ## A legjobb becslő általi eredmények megjelenítése

# %%
best_predictions = grid_search.best_estimator_.predict(extended_train_set_ready_with_standard_scaler)

# %%
best_estimator_scores_ = cross_val_score(grid_search.best_estimator_, extended_train_set_ready_with_standard_scaler, extended_train_labels, scoring="neg_mean_squared_error", cv=10)
best_estimator_scores = np.sqrt(-best_estimator_scores_)
best_estimator_scores
# Out:
# array([0.13973529, 0.13084047, 0.14458547, 0.13723511, 0.13696343,
#        0.13740037, 0.13417535, 0.14467812, 0.12995548, 0.13882545])

# %%
plt.figure(figsize=(6,6))
sns.distplot(best_estimator_scores)
plt.show()

# %%
attributes = ['address', 'name', 'online_order', 'book_table', 'votes', 'dish_liked', 'cuisines', 'approx_cost(for two people)', 'lat', 'lot'] + type_labels + city_labels
sorted(zip(feature_importances, attributes), reverse=True)
# Out:
# [(0.2584187915582178, 'votes'),
#  (0.19799145589059153, 'dish_liked'),
#  (0.09718328976868823, 'cuisines'),
#  (0.0937726546059931, 'name'),
#  (0.09159104857949366, 'approx_cost(for two people)'),
#  (0.09062108320090236, 'address'),
#  (0.07104125689480266, 'book_table'),
#  (0.012716203079226645, 'online_order'),
#  (0.006998638890763737, 'Cafes'),
#  (0.004920120099728685, 'MG Road'),
#  (0.004274552548436875, 'Bellandur'),
#  (0.003657814354818896, 'Residency Road'),
#  (0.003623982354316063, 'Brookefield'),
#  (0.003511919312900785, 'Bannerghatta Road'),
#  (0.0034537257870401634, 'Frazer Town'),
#  (0.0033638678452444734, 'Marathahalli'),
#  (0.0033085702252581063, 'Delivery'),
#  (0.0032921094951283572, 'Buffet'),
#  (0.0030872705884020593, 'Rajajinagar'),
#  (0.0029798392215942835, 'BTM'),
#  (0.002810678431461654, 'Electronic City'),
#  (0.00276815098873871, 'lot'),
#  (0.0026177807990655517, 'Lavelle Road'),
#  (0.002448873753276911, 'New BEL Road'),
#  (0.0023821341656855275, 'Malleshwaram'),
#  (0.0023326788236674076, 'HSR'),
#  (0.002115890752450205, 'Jayanagar'),
#  (0.0020676708932998067, 'JP Nagar'),
#  (0.001828955689077421, 'Drinks & nightlife'),
#  (0.0017473189999941193, 'Banashankari'),
#  (0.0016956301608696983, 'lat'),
#  (0.0016441841138923308, 'Indiranagar'),
#  (0.0015145392730953118, 'Desserts'),
#  (0.0014504473446960244, 'Pubs and bars'),
#  (0.0012365419803717637, 'Church Street'),
#  (0.0010765841532783412, 'Koramangala 5th Block'),
#  (0.0010750330850360483, 'Kalyan Nagar'),
#  (0.001067617629825469, 'Old Airport Road'),
#  (0.0010389501865312495, 'Koramangala 7th Block'),
#  (0.00099329268285441, 'Basavanagudi'),
#  (0.0009653621999720117, 'Koramangala 6th Block'),
#  (0.0009213233786046056, 'Kammanahalli'),
#  (0.000906263437256584, 'Brigade Road'),
#  (0.0008891195706721549, 'Koramangala 4th Block'),
#  (0.0005967832047782051, 'Dine-out')]

# %% [markdown]
# ## Teszt lefuttatása végül, eredmény kijelzése

# %%
final_model = grid_search.best_estimator_

X_extended_test = runPipeline(extended_test_set, False, standardScaler)
y_extended_test = extended_test_labels
print(len(y_test))
X_extended_test_df = pd.DataFrame(X_extended_test)
final_predictions = final_model.predict(X_extended_test_df)
final_mse = mean_squared_error(y_extended_test, final_predictions)
final_rmse = np.sqrt(final_mse)
display_scores(final_rmse)
y_extended_test.plot(kind='hist', label='true values')
pd.Series(final_predictions).plot(kind='hist', label='predictions')
plt.legend()
# Out:
# 8592
# Scores: 0.32428605689205886
# Mean: 0.32428605689205886
# Standard deviation: 0.0

# %% [markdown]
# ## K-Means klaszterezéssel GPS koordináták csoportokba sorolása

# %% [markdown]
# Az előbb elmentett "extended_train_set" felhasználása (ez csak a 'lat' és 'lon' oszlopokat tartalmazza)

# %%
coord_cols_train_df = pd.DataFrame()
coord_cols_train_df['lat'] = extended_train_set['lat']
coord_cols_train_df['lon'] = extended_train_set['lon']

# %%
coord_cols_train = np.array(coord_cols_train_df)

# %% [markdown]
# ### Klaszterezés lefuttatása

# %%
from sklearn.cluster import KMeans

km = KMeans()
y_km = km.fit_predict(coord_cols_train)

# %% [markdown]
# ## Új dataset létrehozása, azon szokásos feldolgozás elvégzése

# %%
dataset_with_zones = zomato.copy()
cleaned_rate_labels = []

dataset_with_zones = dataset_with_zones.loc[dataset_with_zones['rate'] !='NEW']
dataset_with_zones = dataset_with_zones.loc[dataset_with_zones['rate'] !='-'].reset_index(drop=True)

for n in dataset_with_zones['rate']:
    cleaned_rate_labels.append(float(cleanRates(n)))
dataset_with_zones['rate'] = cleaned_rate_labels
dataset_with_zones = dataset_with_zones.drop(dataset_with_zones[np.isnan(dataset_with_zones['rate'])].index)

dataset_with_zones = dataset_with_zones.reset_index()

zones_train_set, zones_test_set = split_train_test_by_id(dataset_with_zones, 0.2, "index")

zones_train_labels = zones_train_set['rate']
zones_train_set = zones_train_set.drop('index', axis=1)
zones_train_set['zone'] = y_km
zones_test_labels = zones_test_set['rate']
zones_test_set = zones_test_set.drop('index', axis=1)

# %%
trainDataWithGivenScalerAndRunAllModels(zones_train_set, zones_train_labels,  standardScaler, "StandardScaler with Zones Data", "No")
# Out:
# Linear Regression with StandardScaler with Zones Data
# Predictions:	 [3.60752273 3.59578332 3.59688767 4.0069045  3.49212397]
# Labels:		    rate
# 0   3.7
# 1   3.9
# 2   4.0
# 3   4.0
# 6   3.2
#
#
# Decision Tree with StandardScaler with Zones Data
# Scores: [0.17748069 0.18663798 0.19576841 0.16998017 0.18865622 0.17509771
#  0.17950643 0.19438753 0.1761566  0.18884046]
# Mean: 0.18325122038456879
# Standard deviation: 0.008323930951272636
#
#
# Random forest with StandardScaler with Zones Data
# Scores: [0.15906249 0.15266575 0.16681434 0.15414856 0.15165801 0.15039963
#  0.15173575 0.16127947 0.1577959  0.15392663]
# Mean: 0.15594865357104784
# Standard deviation: 0.0049461641065473546

# %% [markdown]
# Az adatok végigfuttatása a Pipeline-on, feldolgozott dataset elmentése (zones_train_set_ready_with_standard_scaler).

# %%
zones_train_set_ready_with_standard_scaler = runPipeline(zones_train_set, True, standardScaler)

# %% [markdown]
# ## GridSearch Cross Validation lefuttatása

# %%
grid_search.fit(zones_train_set_ready_with_standard_scaler, zones_train_labels)
# Out:
# GridSearchCV(cv=10, error_score='raise-deprecating',
#        estimator=RandomForestRegressor(bootstrap=True, criterion='mse', max_depth=None,
#            max_features='auto', max_leaf_nodes=None,
#            min_impurity_decrease=0.0, min_impurity_split=None,
#            min_samples_leaf=1, min_samples_split=2,
#            min_weight_fraction_leaf=0.0, n_estimators='warn', n_jobs=None,
#            oob_score=False, random_state=None, verbose=0, warm_start=False),
#        fit_params=None, iid='warn', n_jobs=None,
#        param_grid=[{'bootstrap': [False], 'n_estimators': [10, 15, 20], 'max_features': [3, 5, 10]}],
#        pre_dispatch='2*n_jobs', refit=True, return_train_score='warn',
#        scoring='neg_mean_squared_error', verbose=0)

# %%
cvres = grid_search.cv_results_
for mean_score, params in zip(cvres["mean_test_score"], cvres["params"]):
    print(np.sqrt(-mean_score), params)
print('min: ', np.sqrt(-cvres["mean_test_score"].max()))
# Out:
# 0.2551633614192961 {'bootstrap': False, 'max_features': 3, 'n_estimators': 10}
# 0.250017532036745 {'bootstrap': False, 'max_features': 3, 'n_estimators': 15}
# 0.24657873696824328 {'bootstrap': False, 'max_features': 3, 'n_estimators': 20}
# 0.20845738614037213 {'bootstrap': False, 'max_features': 5, 'n_estimators': 10}
# 0.19904277796779807 {'bootstrap': False, 'max_features': 5, 'n_estimators': 15}
# 0.19690362765038136 {'bootstrap': False, 'max_features': 5, 'n_estimators': 20}
# 0.15146717932636827 {'bootstrap': False, 'max_features': 10, 'n_estimators': 10}
# 0.14640993065410177 {'bootstrap': False, 'max_features': 10, 'n_estimators': 15}
# 0.14436342729823748 {'bootstrap': False, 'max_features': 10, 'n_estimators': 20}
# min:  0.14436342729823748

# %% [markdown]
# ## A legjobb becslő általi eredmények megjelenítése

# %%
best_predictions = grid_search.best_estimator_.predict(zones_train_set_ready_with_standard_scaler)

# %%
best_estimator_scores_ = cross_val_score(grid_search.best_estimator_, zones_train_set_ready_with_standard_scaler, zones_train_labels, scoring="neg_mean_squared_error", cv=10)
best_estimator_scores = np.sqrt(-best_estimator_scores_)
best_estimator_scores
# Out:
# array([0.13803975, 0.14457117, 0.1521389 , 0.14107556, 0.1439995 ,
#        0.1410363 , 0.13685371, 0.1463023 , 0.14079234, 0.1438838 ])

# %%
plt.figure(figsize=(6,6))
sns.distplot(best_estimator_scores)
plt.show()

# %%
attributes = ['address', 'name', 'online_order', 'book_table', 'votes', 'dish_liked', 'cuisines', 'approx_cost(for two people)', 'zones'] + type_labels + city_labels
sorted(zip(feature_importances, attributes), reverse=True)
# Out:
# [(0.2584187915582178, 'votes'),
#  (0.19799145589059153, 'dish_liked'),
#  (0.09718328976868823, 'cuisines'),
#  (0.0937726546059931, 'name'),
#  (0.09159104857949366, 'approx_cost(for two people)'),
#  (0.09062108320090236, 'address'),
#  (0.07104125689480266, 'book_table'),
#  (0.012716203079226645, 'online_order'),
#  (0.006998638890763737, 'Delivery'),
#  (0.004920120099728685, 'Malleshwaram'),
#  (0.004274552548436875, 'Brigade Road'),
#  (0.003657814354818896, 'Sarjapur Road'),
#  (0.003623982354316063, 'Church Street'),
#  (0.003511919312900785, 'Basavanagudi'),
#  (0.0034537257870401634, 'HSR'),
#  (0.0033638678452444734, 'New BEL Road'),
#  (0.0033085702252581063, 'Desserts'),
#  (0.0032921094951283572, 'Cafes'),
#  (0.0030872705884020593, 'Residency Road'),
#  (0.0029798392215942835, 'Banashankari'),
#  (0.002810678431461654, 'Frazer Town'),
#  (0.00276815098873871, 'Buffet'),
#  (0.0026177807990655517, 'MG Road'),
#  (0.002448873753276911, 'Old Airport Road'),
#  (0.0023821341656855275, 'Marathahalli'),
#  (0.0023326788236674076, 'Indiranagar'),
#  (0.002115890752450205, 'Kalyan Nagar'),
#  (0.0020676708932998067, 'Jayanagar'),
#  (0.001828955689077421, 'Pubs and bars'),
#  (0.0017473189999941193, 'Bannerghatta Road'),
#  (0.0016956301608696983, 'zones'),
#  (0.0016441841138923308, 'JP Nagar'),
#  (0.0015145392730953118, 'Dine-out'),
#  (0.0014504473446960244, 'BTM'),
#  (0.0012365419803717637, 'Electronic City'),
#  (0.0010765841532783412, 'Koramangala 6th Block'),
#  (0.0010750330850360483, 'Kammanahalli'),
#  (0.001067617629825469, 'Rajajinagar'),
#  (0.0010389501865312495, 'Lavelle Road'),
#  (0.00099329268285441, 'Bellandur'),
#  (0.0009653621999720117, 'Koramangala 7th Block'),
#  (0.0009213233786046056, 'Koramangala 4th Block'),
#  (0.000906263437256584, 'Brookefield'),
#  (0.0008891195706721549, 'Koramangala 5th Block'),
#  (0.0005967832047782051, 'Drinks & nightlife')]

# %% [markdown]
# ## K-Means klaszterezés ellenőrzése

# %%
X_loc = coord_cols_train.copy()
y_loc = y_km.copy()

# %% [markdown]
# Először a tanító szettet is szétszedjük és azon is ellenőrzünk a K Nearest Neighbors klaszterezés segítségével.

# %%
from sklearn.model_selection import train_test_split  
X_loc_train, X_loc_test, y_loc_train, y_loc_test = train_test_split(X_loc, y_loc, test_size=0.20)

# %%
from sklearn.neighbors import KNeighborsClassifier  
classifier = KNeighborsClassifier(n_neighbors=8)  
classifier.fit(X_loc_train, y_loc_train)
# Out:
# KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#            metric_params=None, n_jobs=None, n_neighbors=8, p=2,
#            weights='uniform')

# %%
y_pred = classifier.predict(X_loc_test)

# %% [markdown]
# Amint látni, 100%-ig egyeznek a prediktált értékek.

# %%
from sklearn.metrics import classification_report, confusion_matrix  
print(confusion_matrix(y_loc_test, y_pred))  
print(classification_report(y_loc_test, y_pred))
# Out:
# [[ 486    0    0    0    0    0    0    0]
#  [   0  123    0    0    0    0    0    0]
#  [   0    0  780    0    0    0    0    0]
#  [   0    0    0  563    0    0    0    0]
#  [   0    0    0    0 1536    0    0    0]
#  [   0    0    0    0    0 2043    0    0]
#  [   0    0    0    0    0    0  245    0]
#  [   0    0    0    0    0    0    0  839]]
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00       486
#            1       1.00      1.00      1.00       123
#            2       1.00      1.00      1.00       780
#            3       1.00      1.00      1.00       563
#            4       1.00      1.00      1.00      1536
#            5       1.00      1.00      1.00      2043
#            6       1.00      1.00      1.00       245
#            7       1.00      1.00      1.00       839
#
#    micro avg       1.00      1.00      1.00      6615
#    macro avg       1.00      1.00      1.00      6615
# weighted avg       1.00      1.00      1.00      6615

# %% [markdown]
# Majd a teszt szetten is megjósoljuk a kategóriákat és hozzáadjuk a teszt szetthez az oszlopot.

# %%
coord_cols_test_df = pd.DataFrame()
coord_cols_test_df['lat'] = extended_test_set['lat']
coord_cols_test_df['lon'] = extended_test_set['lon']
coord_cols_test = np.array(coord_cols_test_df)


y_test_pred = classifier.predict(coord_cols_test)

# %%
zones_test_set['zones'] = y_test_pred

# %% [markdown]
# ## Teszt lefuttatása végül, eredmény kijelzése

# %%
final_model = grid_search.best_estimator_

X_zones_test = runPipeline(zones_test_set, False, standardScaler)
y_zones_test = zones_test_labels
print(len(y_test))
X_zones_test_df = pd.DataFrame(X_zones_test)
final_predictions = final_model.predict(X_zones_test_df)
final_mse = mean_squared_error(y_zones_test, final_predictions)
final_rmse = np.sqrt(final_mse)
display_scores(final_rmse)
y_zones_test.plot(kind='hist', label='true values')
pd.Series(final_predictions).plot(kind='hist', label='predictions')
plt.legend()
# Out:
# 8592
# Scores: 0.3201286776096749
# Mean: 0.3201286776096749
# Standard deviation: 0.0

# %%
statistic_table.sort_values(by=['mean'])
# Out:
#                              details      mean                   name purging  \
# 14  StandardScaler with Lat Lon Data  0.154750  RandomForestRegressor      No
# 17    StandardScaler with Zones Data  0.155949  RandomForestRegressor      No
# 5     StandardScaler with Basic Data  0.161602  RandomForestRegressor      No
# 2         MinMaxNorm with Basic Data  0.162371  RandomForestRegressor      No
# 8        MinMaxNorm with Purged Data  0.172799  RandomForestRegressor     Yes
# 11  StandardScaler  with Purged Data  0.174161  RandomForestRegressor     Yes
# 13  StandardScaler with Lat Lon Data  0.183120  DecisionTreeRegressor      No
# 16    StandardScaler with Zones Data  0.183251  DecisionTreeRegressor      No
# 1         MinMaxNorm with Basic Data  0.194661  DecisionTreeRegressor      No
# 4     StandardScaler with Basic Data  0.196045  DecisionTreeRegressor      No
# 7        MinMaxNorm with Purged Data  0.209879  DecisionTreeRegressor     Yes
# 10  StandardScaler  with Purged Data  0.210709  DecisionTreeRegressor     Yes
# 6        MinMaxNorm with Purged Data  0.343548       LinearRegression     Yes
# 9   StandardScaler  with Purged Data  0.343548       LinearRegression     Yes
# 15    StandardScaler with Zones Data  0.345623       LinearRegression      No
# 12  StandardScaler with Lat Lon Data  0.346885       LinearRegression      No
# 0         MinMaxNorm with Basic Data  0.346925       LinearRegression      No
# 3     StandardScaler with Basic Data  0.346951       LinearRegression      No
#
#             rmse standard deviation
# 14  6.329714e-02         0.00418849
# 17  6.479378e-02         0.00494616
# 5   6.746340e-02         0.00306589
# 2   6.724757e-02         0.00389017
# 8   7.070615e-02         0.00840326
# 11  7.124273e-02         0.00835034
# 13  6.251296e-16         0.00829264
# 16  6.131874e-16         0.00832393
# 1   6.206206e-16         0.00765563
# 4   6.206734e-16         0.00645229
# 7   6.215375e-16          0.0199013
# 10  6.212784e-16          0.0226635
# 6   3.435484e-01                NaN
# 9   3.435484e-01                NaN
# 15  3.456229e-01                NaN
# 12  3.468850e-01                NaN
# 0   3.469253e-01                NaN
# 3   3.469507e-01                NaN

# %%
coord_cols_df = pd.DataFrame()
coord_cols_df['lat'] = not_scaled_extended_train_set['lat']
coord_cols_df['lon'] = not_scaled_extended_train_set['lon']
coord_cols_ = np.array(coord_cols_df)

# %% [markdown]
# Kiszedjük a -1-es sorokat, hogy meg tudjuk állapítani a legkisebb értékeket, amikkel körbehatárolhatjuk a térképet a vizualizációnál.

# %%
coord_cols_del = [x for x in coord_cols_ if x[0] != -1.0]

# %%
lower_lat = min(coord_cols_del, key = lambda t: t[1])[1] 
lower_lon = min(coord_cols_del, key = lambda t: t[0])[0]
upper_lat = max(coord_cols_del, key = lambda t: t[1])[1]
upper_lon = max(coord_cols_del, key = lambda t: t[0])[0]

# %%
print(lower_lat)
print(lower_lon)
print(upper_lat)
print(upper_lon)
# Out:
# 77.4333346
# 12.9055682
# 77.7519261
# 13.3457317

# %% [markdown]
# Kiszedjük az egyedi értékeket (először tuple formába konvertáljuk, hogy megmaradjanak az adatkettesek), a hozzájuk tartozó "zónákkal" párban.

# %%
tuple_coords = []
for x in coord_cols_:
    tuple_coords.append((x[0], x[1]))
unique_tuple_coords = np.unique(tuple_coords, return_index = True, axis = 0)   
unique_y_km = []
for x in unique_tuple_coords[1]:
    unique_y_km.append(y_km[x])

# %% [markdown]
# Kirajzoltatjuk az egyedi koordinátákat (hiszen nem lehet/ nincs értelme ugyanazt a pontot többször), különböző zónákat különböző színnel.
# Itt viszont az eredeti koordinátákat kell felhasználnunk, hiszen a skálázott értékekkel nem lehet jól vizualizálni.

# %%
from mpl_toolkits.basemap import Basemap

m=Basemap(llcrnrlon = lower_lon - 0.02, llcrnrlat = lower_lat - 0.02, urcrnrlon = upper_lon + 0.02 , urcrnrlat = upper_lat + 0.02)
m.drawmapboundary(fill_color='#A6CAE0', linewidth=0)
m.fillcontinents(color='grey', alpha=0.7, lake_color='grey')
m.drawcoastlines(linewidth=0.1, color="white")

for coord, zona in zip(unique_tuple_coords[0], unique_y_km):
    if zona == 0:
        m.plot(coord[0], coord[1], linestyle='none', marker="o", markersize=16, alpha=0.6, c="black", markeredgecolor="black", markeredgewidth=1)
    if zona == 1:
        m.plot(coord[0], coord[1], linestyle='none', marker="o", markersize=16, alpha=0.6, c="orange", markeredgecolor="black", markeredgewidth=1)
    if zona == 2:
        m.plot(coord[0], coord[1], linestyle='none', marker="o", markersize=16, alpha=0.6, c="red", markeredgecolor="black", markeredgewidth=1)
    if zona == 3:
        m.plot(coord[0], coord[1], linestyle='none', marker="o", markersize=16, alpha=0.6, c="yellow", markeredgecolor="black", markeredgewidth=1)
    if zona == 4:
        m.plot(coord[0], coord[1], linestyle='none', marker="o", markersize=16, alpha=0.6, c="blue", markeredgecolor="black", markeredgewidth=1)
    if zona == 5:
        m.plot(coord[0], coord[1], linestyle='none', marker="o", markersize=16, alpha=0.6, c="green", markeredgecolor="black", markeredgewidth=1)
    if zona == 6:
        m.plot(coord[0], coord[1], linestyle='none', marker="o", markersize=16, alpha=0.6, c="brown", markeredgecolor="black", markeredgewidth=1)
    if zona == 7:
        m.plot(coord[0], coord[1], linestyle='none', marker="o", markersize=16, alpha=0.6, c="purple", markeredgecolor="black", markeredgewidth=1)

# %%
from collections import Counter
Counter(unique_y_km)
# Out:
# Counter({1: 1, 4: 9, 7: 11, 0: 9, 5: 24, 3: 12, 6: 10, 2: 2})

# %%
test_statistic_table = pd.DataFrame()

def printToTestStatistics(name, score):
    global test_statistic_table 
    test_statistic_table = test_statistic_table.append({'name' : name , 
                                              'score' : score
                                             } , ignore_index=True)
    
printToTestStatistics("Test with Basic Data", final_rmse)
printToTestStatistics("Test with Lat Lon Data", final_rmse)
printToTestStatistics("Test with Zones Data", final_rmse)
